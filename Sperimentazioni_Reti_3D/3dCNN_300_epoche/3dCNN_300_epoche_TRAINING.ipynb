# %% [markdown]
# # Setup
# Inizia installando e importando alcune librerie necessarie, tra cui: `tqdm` per utilizzare una barra di avanzamento, `OpenCV` per elaborare file video, `einops` per eseguire operazioni tensoriali più complesse e `tensorflow_docs` per incorporare i dati in un notebook Jupyter.

# %%
# The way this tutorial uses the `TimeDistributed` layer requires TF>=2.10
# !pip install -U "tensorflow==2.10.0"
# !pip install -U "einops"
# Out:
# Requirement already satisfied: tensorflow==2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (23.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (49.2.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (4.6.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.54.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.19.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Requirement already satisfied: einops in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (0.6.1)

# %%
# !pip install tqdm opencv-python numpy matplotlib imageio seaborn
# !pip install tensorflow-docs
# Out:
# Requirement already satisfied: tqdm in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.65.0)
# Requirement already satisfied: opencv-python in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (3.7.1)
# Requirement already satisfied: imageio in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (2.29.0)
# Requirement already satisfied: seaborn in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (0.12.2)
# Requirement already satisfied: colorama in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tensorflow-docs in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (2023.5.26.9808)
# Requirement already satisfied: astor in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (0.8.1)
# Requirement already satisfied: absl-py in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (1.4.0)
# Requirement already satisfied: jinja2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (3.1.2)
# Requirement already satisfied: nbformat in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (5.8.0)
# Requirement already satisfied: protobuf>=3.12 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (3.19.6)
# Requirement already satisfied: pyyaml in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from jinja2->tensorflow-docs) (2.1.2)
# Requirement already satisfied: fastjsonschema in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from nbformat->tensorflow-docs) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from nbformat->tensorflow-docs) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from nbformat->tensorflow-docs) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from nbformat->tensorflow-docs) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs) (0.19.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from jupyter-core->nbformat->tensorflow-docs) (3.5.1)
# Requirement already satisfied: pywin32>=300 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from jupyter-core->nbformat->tensorflow-docs) (306)

# %%
import seaborn as sns

import tqdm
import random
import pathlib
import itertools
import collections

import os
import cv2
import numpy as np

import tensorflow as tf

import shutil #roba fresca aggiunta da poco
import matplotlib.pyplot as plt 

# Some modules to display an animation using imageio.
import imageio
from IPython import display
from urllib import request
from tensorflow_docs.vis import embed

import keras
from keras import layers
import einops

# %% [markdown]
# # Fase di Pre-processing
# Si noti che il nome della classe è incluso nel nome del file di ogni video.
#
# Definire la funzione `get_class` che recupera il nome della classe da un nome di file. Quindi, creare una funzione chiamata `get_files_per_class` che converte l'elenco di tutti i file (file sopra) in un dizionario che elenca i file per ogni classe:

# %%
def get_class(fname):
  """ Retrieve the name of the class given a filename.

    Args:
      fname: Name of the file in the UCF101 dataset.

    Returns:
      Class that the file belongs to.
  """
  return fname.split('_')[-7]

# %%
def get_files_per_class(files):
  """ Retrieve the files that belong to each class.

    Args:
      files: List of files in the dataset.

    Returns:
      Dictionary of class names (key) and files (values). 
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %% [markdown]
# Il seguente blocco serve per contare i file video di tipo `*.avi `in tutte le sottocartelle del dataset

# %%
download_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val")

video_count_train = len(list(download_dir.glob('Train/*/*.avi')))
video_count_val = len(list(download_dir.glob('Validation/*/*.avi')))
video_count_test = len(list(download_dir.glob('Test/*/*.avi')))
video_total = video_count_train + video_count_val + video_count_test

print(f"print_train: {video_count_train}")
print(f"print_val: {video_count_val}")
print(f"print_test: {video_count_test}")
print(f"Total videos: {video_total}")
# Out:
# print_train: 960
# print_val: 160
# print_test: 160
# Total videos: 1280

# %% [markdown]
# # Crea fotogrammi da ogni file video

# %% [markdown]
# La funzione `frames_from_video_file` divide i video in frame, legge un intervallo scelto a caso di `n_frame` da un file video e li restituisce come `array` NumPy. Per ridurre la memoria e il sovraccarico di calcolo, scegliere un piccolo numero di fotogrammi. Inoltre, scegli lo stesso numero di fotogrammi da ogni video, il che rende più facile lavorare su lotti di dati.

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.
    
    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

# %%
def frames_from_video_file(video_path, n_frames, output_size = (40,60), frame_step = 3):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))  

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

# %% [markdown]
# # Visualizza i dati video

# %% [markdown]
# Snippet di
# codice per fare un gif dato un video preso a caso nella cartella di Train

# %%
def to_gif(images):
  converted_images = np.clip(images * 255, 0, 255).astype(np.uint8)
  imageio.mimsave('./animation.gif', converted_images, duration=125)
  return embed.embed_file('./animation.gif')

# docs-infra: no-execute
ucf_sample_video = frames_from_video_file(next(download_dir.glob('Train/*/*.avi')), 80)
to_gif(ucf_sample_video)
# Out:
# <img src="data:image/gif;base64,..."/>

# %% [markdown]
# Successivamente, definire la classe `FrameGenerator` per creare un oggetto iterabile in grado di immettere dati nella pipeline di dati TensorFlow. La funzione generatore `(__call__)` produce l'array di frame prodotto da `frames_from_video_file` e un vettore codificato one-hot dell'etichetta associata all'insieme di frame.

# %%
class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.avi'))
    classes = [p.parent.name for p in video_paths] 
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames) 
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %% [markdown]
# Creiamo il training, il  validation e il test sets (train_ds, val_ds, test_ds).

# %%
n_frames = 12
batch_size = 32

train_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Train")
test_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Test")
val_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Validation")

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_ds = tf.data.Dataset.from_generator(FrameGenerator(train_dir, n_frames, training=True),
                                          output_signature = output_signature)


# Batch the data
train_ds = train_ds.batch(batch_size)

val_ds = tf.data.Dataset.from_generator(FrameGenerator(val_dir, n_frames),
                                        output_signature = output_signature)
val_ds = val_ds.batch(batch_size)

test_ds = tf.data.Dataset.from_generator(FrameGenerator(test_dir, n_frames),
                                         output_signature = output_signature)
test_ds = test_ds.batch(batch_size)

# %% [markdown]
# # Creazione del modello

# %% [markdown]
# Il seguente modello di rete neurale convoluzionale 3D si basa sul documento A Closer Look at Spatiotemporal Convolutions for Action Recognition di D. Tran et al. (2017). Il documento confronta diverse versioni di 3D ResNets. Invece di operare su una singola immagine con dimensioni `(altezza, larghezza)`, come le ResNet standard, queste operano sul volume video `(tempo, altezza, larghezza)`. L'approccio più ovvio a questo problema sarebbe sostituire ogni convoluzione 2D `(layers.Conv2D)` con una convoluzione 3D `(layers.Conv3D)`.
#
# Questo progetto utilizza una convoluzione (2 + 1)D con connessioni residue. La convoluzione (2 + 1)D consente la decomposizione delle dimensioni spaziali e temporali, creando quindi due passaggi separati. Un vantaggio di questo approccio è che la fattorizzazione delle convoluzioni in dimensioni spaziali e temporali salva i parametri.
#
# Per ogni posizione di uscita una convoluzione 3D combina tutti i vettori da una patch 3D del volume per creare un vettore nel volume di uscita.
# ![3DCNN.png](data:image/png;base64,...)
#
# Questa operazione richiede `time * height * width * channels` inputs e produce `channels` uscite (supponendo che il numero di canali di ingresso e di uscita siano gli stessi. Quindi un livello di convoluzione 3D con una dimensione del kernel di `(3 x 3 x 3)` avrebbe bisogno di una matrice di peso con `27 * channels ** 2` voci. Il documento di riferimento ha rilevato che un approccio più efficace ed efficiente era quello di fattorizzare la convoluzione. Invece di una singola convoluzione 3D per elaborare le dimensioni del tempo e dello spazio, hanno proposto una convoluzione "(2+1)D" che elabora le dimensioni dello spazio e del tempo separatamente. La figura seguente mostra le convoluzioni spaziali e temporali fattorizzate di una convoluzione (2 + 1)D.
# ![2plus1CNN.png](data:image/png;base64,...)
#
# Il vantaggio principale di questo approccio è che riduce il numero di parametri. Nella convoluzione (2 + 1)D la convoluzione spaziale prende i dati della forma `(1, width, height)`, mentre la convoluzione temporale prende i dati della forma `(time, 1, 1)`. Ad esempio, una convoluzione (2 + 1)D con dimensioni del kernel `(3 x 3 x 3)` avrebbe bisogno di matrici di peso di dimensioni `(9 * channels **2) + (3 * channels **2),` meno della metà della convoluzione 3D completa. Questo progetto implementa (2 + 1)D ResNet18, in cui ogni convoluzione nella resnet è sostituita da una convoluzione (2+1)D.

# %%
# Define the dimensions of one frame in the set of frames created
HEIGHT = 40
WIDTH = 60

# %%
class Conv2Plus1D(keras.layers.Layer):
  def __init__(self, filters, kernel_size, padding):
    """
      A sequence of convolutional layers that first apply the convolution operation over the
      spatial dimensions, and then the temporal dimension. 
    """
    super().__init__()
    self.seq = keras.Sequential([  
        # Spatial decomposition
        layers.Conv3D(filters=filters,
                      kernel_size=(1, kernel_size[1], kernel_size[2]),
                      padding=padding),
        # Temporal decomposition
        layers.Conv3D(filters=filters, 
                      kernel_size=(kernel_size[0], 1, 1),
                      padding=padding)
        ])

  def call(self, x):
    return self.seq(x)

# %% [markdown]
# Un modello ResNet resnet è costituito da una sequenza di blocchi residui. Un blocco residuo ha due rami. Il ramo principale esegue la calculatoion, ma è difficile per i gradienti passare attraverso. Il ramo residuo bypassa il calcolo principale e per lo più aggiunge solo l'input all'output del ramo principale. I gradienti scorrono facilmente attraverso questo ramo. Pertanto, sarà presente un percorso facile dalla funzione di perdita a uno qualsiasi dei rami principali del blocco residuo. Questo evita il problema del gradiente di fuga.
#
# Creare il ramo principale del blocco residuo con la seguente classe. A differenza della struttura ResNet standard, questo utilizza il layer Conv2Plus1D personalizzato invece di layers.Conv2D.

# %%
class ResidualMain(keras.layers.Layer):
  """
    Residual block of the model with convolution, layer normalization, and the
    activation function, ReLU.
  """
  def __init__(self, filters, kernel_size):
    super().__init__()
    self.seq = keras.Sequential([
        Conv2Plus1D(filters=filters,
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization(),
        layers.ReLU(),
        Conv2Plus1D(filters=filters, 
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %% [markdown]
# Per aggiungere il ramo residuo al ramo principale deve avere le stesse dimensioni. Il livello di progetto riportato di seguito si occupa dei casi in cui il numero di canali viene modificato sul ramo. In particolare, viene aggiunta una sequenza di strato densamente connesso seguito dalla normalizzazione.

# %%
class Project(keras.layers.Layer):
  """
    Project certain dimensions of the tensor as the data is passed through different 
    sized filters and downsampled. 
  """
  def __init__(self, units):
    super().__init__()
    self.seq = keras.Sequential([
        layers.Dense(units),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %% [markdown]
# Utilizzare `add_residual_block` per introdurre una connessione skip tra i layer del modello.

# %%
def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(filters, 
                     kernel_size)(input)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(out.shape[-1])(res)

  return layers.add([res, out])

# %% [markdown]
# Il ridimensionamento del video è necessario per eseguire il downsampling dei dati. In particolare, il downsampling dei fotogrammi video consente al modello di esaminare parti specifiche dei fotogrammi per rilevare modelli che possono essere specifici per una determinata azione. Attraverso il downsampling, le informazioni non essenziali possono essere scartate. Inoltre, il ridimensionamento del video consentirà una riduzione della dimensionalità e quindi un'elaborazione più rapida attraverso il modello.

# %%
class ResizeVideo(keras.layers.Layer):
  def __init__(self, height, width):
    super().__init__()
    self.height = height
    self.width = width
    self.resizing_layer = layers.Resizing(self.height, self.width)

  def call(self, video):
    """
      Use the einops library to resize the tensor.  

      Args:
        video: Tensor representation of the video, in the form of a set of frames.

      Return:
        A downsampled size of the video according to the new height and width it should be resized to.
    """
    # b stands for batch size, t stands for time, h stands for height, 
    # w stands for width, and c stands for the number of channels.
    old_shape = einops.parse_shape(video, 'b t h w c')
    images = einops.rearrange(video, 'b t h w c -> (b t) h w c')
    images = self.resizing_layer(images)
    videos = einops.rearrange(
        images, '(b t) h w c -> b t h w c',
        t = old_shape['t'])
    return videos

# %% [markdown]
# Uso l'API Funtion di Keras per costruire la rete residua.

# %%
input_shape = (None, n_frames, HEIGHT, WIDTH, 3)
input = layers.Input(shape=(input_shape[1:]))
x = input

x = Conv2Plus1D(filters=16, kernel_size=(3, 7, 7), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = ResizeVideo(HEIGHT // 2, WIDTH // 2)(x)

# Block 1
x = add_residual_block(x, 8, (3, 3, 3))
x = ResizeVideo(HEIGHT // 4, WIDTH // 4)(x)

# Block 2
x = add_residual_block(x, 16, (3, 3, 3))
x = ResizeVideo(HEIGHT // 8, WIDTH // 8)(x)

# Block 3
x = add_residual_block(x, 32, (3, 3, 3))

x = layers.GlobalAveragePooling3D()(x)

x = layers.Flatten()(x)

x = layers.Dropout(0.5)(x)

x = layers.Dense(8, activation='softmax')(x)

model = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds))
model.build(frames)

# %% [markdown]
# ## Traino il modello

# %% [markdown]
# Per questo progetto, è stato scelto l'ottimizzatore `tf.keras.optimizers.Adam` e la funzione di loss `tf.keras.losses.SparseCategoricalCrossentropy` che è indicata per i modelli multi-classe. Utilizzare l'argomento delle metriche per visualizzare l'accuratezza delle prestazioni del modello in ogni fase.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 12, 40, 60,  0           []
#                                  3)]
#
#  conv2_plus1d (Conv2Plus1D)     (None, 12, 40, 60,   3152        ['input_1[0][0]']
#                                 16)
#
#  batch_normalization (BatchNorm  (None, 12, 40, 60,   64         ['conv2_plus1d[0][0]']
#  alization)                     16)
#
#  re_lu (ReLU)                   (None, 12, 40, 60,   0           ['batch_normalization[0][0]']
#                                 16)
#
#  resize_video (ResizeVideo)     (None, 12, 20, 30,   0           ['re_lu[0][0]']
#                                 16)
#
#  project (Project)              (None, 12, 20, 30,   152         ['resize_video[0][0]']
#                                 8)
#
#  residual_main (ResidualMain)   (None, 12, 20, 30,   2176        ['resize_video[0][0]']
#                                 8)
#
#  add (Add)                      (None, 12, 20, 30,   0           ['project[0][0]',
#                                 8)                                'residual_main[0][0]']
#
#  resize_video_1 (ResizeVideo)   (None, 12, 10, 15,   0           ['add[0][0]']
#                                 8)
#
#  project_1 (Project)            (None, 12, 10, 15,   176         ['resize_video_1[0][0]']
#                                 16)
#
#  residual_main_1 (ResidualMain)  (None, 12, 10, 15,   5120       ['resize_video_1[0][0]']
#                                 16)
#
#  add_1 (Add)                    (None, 12, 10, 15,   0           ['project_1[0][0]',
#                                 16)                               'residual_main_1[0][0]']
#
#  resize_video_2 (ResizeVideo)   (None, 12, 5, 7, 16  0           ['add_1[0][0]']
#                                 )
#
#  project_2 (Project)            (None, 12, 5, 7, 32  608         ['resize_video_2[0][0]']
#                                 )
#
#  residual_main_2 (ResidualMain)  (None, 12, 5, 7, 32  20224      ['resize_video_2[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 12, 5, 7, 32  0           ['project_2[0][0]',
#                                 )                                 'residual_main_2[0][0]']
#
#  global_average_pooling3d (Glob  (None, 32)          0           ['add_2[0][0]']
#  alAveragePooling3D)
#
#  flatten (Flatten)              (None, 32)           0           ['global_average_pooling3d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 32)           0           ['flatten[0][0]']
#
#  dense_3 (Dense)                (None, 8)            264         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 31,936
# Trainable params: 31,904
# Non-trainable params: 32
# __________________________________________________________________________________________________

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.001), 
              metrics = ['accuracy'])

# %% [markdown]
# Addestra il modello per 10 epoche con il metodo Keras `model.fit`.

# %%
history = model.fit(x = train_ds,
                    epochs = 300,
                    shuffle= True,
                    validation_data = val_ds)
# Out:
# Epoch 1/300
# c:\Users\Vincenzo\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 30/30 [==============================] - 108s 3s/step - loss: 2.4345 - accuracy: 0.1396 - val_loss: 2.2668 - val_accuracy: 0.1250
# Epoch 2/300
# 30/30 [==============================] - 99s 3s/step - loss: 2.1199 - accuracy: 0.1615 - val_loss: 2.2146 - val_accuracy: 0.1125
# Epoch 3/300
# 30/30 [==============================] - 98s 3s/step - loss: 2.1038 - accuracy: 0.1542 - val_loss: 2.2966 - val_accuracy: 0.0562
# Epoch 4/300
# 30/30 [==============================] - 92s 3s/step - loss: 2.0366 - accuracy: 0.1979 - val_loss: 2.0544 - val_accuracy: 0.1437
# Epoch 5/300
# 30/30 [==============================] - 88s 3s/step - loss: 2.0041 - accuracy: 0.2104 - val_loss: 2.1291 - val_accuracy: 0.1562
# Epoch 6/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.9921 - accuracy: 0.2240 - val_loss: 2.1115 - val_accuracy: 0.1437
# Epoch 7/300
# 30/30 [==============================] - 94s 3s/step - loss: 1.9574 - accuracy: 0.2521 - val_loss: 2.0302 - val_accuracy: 0.1937
# Epoch 8/300
# 30/30 [==============================] - 100s 3s/step - loss: 1.9588 - accuracy: 0.2375 - val_loss: 2.0419 - val_accuracy: 0.2750
# Epoch 9/300
# 30/30 [==============================] - 93s 3s/step - loss: 1.9499 - accuracy: 0.2458 - val_loss: 2.5059 - val_accuracy: 0.1937
# Epoch 10/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.9188 - accuracy: 0.2615 - val_loss: 2.1130 - val_accuracy: 0.1437
# Epoch 11/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.8883 - accuracy: 0.2875 - val_loss: 2.1012 - val_accuracy: 0.1937
# Epoch 12/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.8644 - accuracy: 0.3063 - val_loss: 2.2142 - val_accuracy: 0.1437
# Epoch 13/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.8298 - accuracy: 0.3010 - val_loss: 2.0084 - val_accuracy: 0.2250
# Epoch 14/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.8264 - accuracy: 0.3042 - val_loss: 2.0740 - val_accuracy: 0.1875
# Epoch 15/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.7916 - accuracy: 0.3333 - val_loss: 2.1658 - val_accuracy: 0.2062
# Epoch 16/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.7888 - accuracy: 0.3375 - val_loss: 1.8394 - val_accuracy: 0.3750
# Epoch 17/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.7453 - accuracy: 0.3438 - val_loss: 2.2346 - val_accuracy: 0.2937
# Epoch 18/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.6843 - accuracy: 0.3792 - val_loss: 2.4267 - val_accuracy: 0.2625
# Epoch 19/300
# 30/30 [==============================] - 89s 3s/step - loss: 1.7016 - accuracy: 0.3573 - val_loss: 1.8682 - val_accuracy: 0.3562
# Epoch 20/300
# 30/30 [==============================] - 89s 3s/step - loss: 1.6652 - accuracy: 0.3833 - val_loss: 2.2322 - val_accuracy: 0.3375
# Epoch 21/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.6422 - accuracy: 0.3729 - val_loss: 2.2300 - val_accuracy: 0.2750
# Epoch 22/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.6110 - accuracy: 0.4021 - val_loss: 1.7841 - val_accuracy: 0.3375
# Epoch 23/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.5799 - accuracy: 0.3865 - val_loss: 2.0294 - val_accuracy: 0.2062
# Epoch 24/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.5898 - accuracy: 0.3938 - val_loss: 1.9343 - val_accuracy: 0.3063
# Epoch 25/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.5650 - accuracy: 0.4021 - val_loss: 2.1334 - val_accuracy: 0.1688
# Epoch 26/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.4980 - accuracy: 0.4521 - val_loss: 1.8451 - val_accuracy: 0.2937
# Epoch 27/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.5148 - accuracy: 0.4385 - val_loss: 1.9183 - val_accuracy: 0.3875
# Epoch 28/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.4769 - accuracy: 0.4490 - val_loss: 1.8353 - val_accuracy: 0.3438
# Epoch 29/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.4325 - accuracy: 0.4688 - val_loss: 1.6575 - val_accuracy: 0.3187
# Epoch 30/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.4114 - accuracy: 0.4750 - val_loss: 1.9062 - val_accuracy: 0.3000
# Epoch 31/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.4385 - accuracy: 0.4635 - val_loss: 1.7990 - val_accuracy: 0.3625
# Epoch 32/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.4016 - accuracy: 0.4740 - val_loss: 1.9027 - val_accuracy: 0.3562
# Epoch 33/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.3152 - accuracy: 0.5073 - val_loss: 1.8152 - val_accuracy: 0.3938
# Epoch 34/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.3228 - accuracy: 0.5063 - val_loss: 2.1712 - val_accuracy: 0.3812
# Epoch 35/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.3381 - accuracy: 0.5021 - val_loss: 2.2211 - val_accuracy: 0.3125
# Epoch 36/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.2741 - accuracy: 0.5406 - val_loss: 2.3656 - val_accuracy: 0.2688
# Epoch 37/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.2636 - accuracy: 0.5156 - val_loss: 1.8971 - val_accuracy: 0.3250
# Epoch 38/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.2629 - accuracy: 0.5323 - val_loss: 1.9504 - val_accuracy: 0.3500
# Epoch 39/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.2432 - accuracy: 0.5125 - val_loss: 1.7362 - val_accuracy: 0.3375
# Epoch 40/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.2735 - accuracy: 0.5063 - val_loss: 2.0803 - val_accuracy: 0.2875
# Epoch 41/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.2243 - accuracy: 0.5500 - val_loss: 1.9390 - val_accuracy: 0.3750
# Epoch 42/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.1900 - accuracy: 0.5667 - val_loss: 1.6600 - val_accuracy: 0.4313
# Epoch 43/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.1125 - accuracy: 0.5823 - val_loss: 2.3289 - val_accuracy: 0.2688
# Epoch 44/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.1446 - accuracy: 0.5719 - val_loss: 2.4475 - val_accuracy: 0.2750
# Epoch 45/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.1167 - accuracy: 0.5906 - val_loss: 2.0143 - val_accuracy: 0.3688
# Epoch 46/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.0435 - accuracy: 0.6250 - val_loss: 2.2123 - val_accuracy: 0.3000
# Epoch 47/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.1027 - accuracy: 0.6083 - val_loss: 2.4265 - val_accuracy: 0.3125
# Epoch 48/300
# 30/30 [==============================] - 87s 3s/step - loss: 1.0107 - accuracy: 0.6438 - val_loss: 2.0637 - val_accuracy: 0.3000
# Epoch 49/300
# 30/30 [==============================] - 88s 3s/step - loss: 1.0222 - accuracy: 0.6500 - val_loss: 2.2485 - val_accuracy: 0.3187
# Epoch 50/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.9892 - accuracy: 0.6448 - val_loss: 1.9121 - val_accuracy: 0.3438
# Epoch 51/300
# 30/30 [==============================] - 89s 3s/step - loss: 0.9729 - accuracy: 0.6542 - val_loss: 2.0606 - val_accuracy: 0.3187
# Epoch 52/300
# 30/30 [==============================] - 89s 3s/step - loss: 0.9826 - accuracy: 0.6469 - val_loss: 2.1079 - val_accuracy: 0.2812
# Epoch 53/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.9117 - accuracy: 0.6656 - val_loss: 2.4118 - val_accuracy: 0.2625
# Epoch 54/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.9457 - accuracy: 0.6656 - val_loss: 2.0456 - val_accuracy: 0.3438
# Epoch 55/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.8744 - accuracy: 0.7115 - val_loss: 2.1748 - val_accuracy: 0.3562
# Epoch 56/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.9274 - accuracy: 0.6667 - val_loss: 2.2832 - val_accuracy: 0.4375
# Epoch 57/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.8847 - accuracy: 0.6771 - val_loss: 2.5210 - val_accuracy: 0.3000
# Epoch 58/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.8814 - accuracy: 0.6885 - val_loss: 2.1387 - val_accuracy: 0.3125
# Epoch 59/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.9289 - accuracy: 0.6687 - val_loss: 1.8821 - val_accuracy: 0.3875
# Epoch 60/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.9311 - accuracy: 0.6594 - val_loss: 2.8448 - val_accuracy: 0.2438
# Epoch 61/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.8064 - accuracy: 0.7365 - val_loss: 2.3024 - val_accuracy: 0.4437
# Epoch 62/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.8157 - accuracy: 0.7125 - val_loss: 2.2701 - val_accuracy: 0.3938
# Epoch 63/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.7336 - accuracy: 0.7323 - val_loss: 2.2943 - val_accuracy: 0.3562
# Epoch 64/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.7436 - accuracy: 0.7417 - val_loss: 2.4168 - val_accuracy: 0.3500
# Epoch 65/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.8243 - accuracy: 0.6938 - val_loss: 2.5127 - val_accuracy: 0.3500
# Epoch 66/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.6798 - accuracy: 0.7656 - val_loss: 2.5197 - val_accuracy: 0.3438
# Epoch 67/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.7229 - accuracy: 0.7490 - val_loss: 2.9394 - val_accuracy: 0.2875
# Epoch 68/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6597 - accuracy: 0.7844 - val_loss: 2.5106 - val_accuracy: 0.3438
# Epoch 69/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.7756 - accuracy: 0.7229 - val_loss: 2.1629 - val_accuracy: 0.3750
# Epoch 70/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.7252 - accuracy: 0.7458 - val_loss: 2.3537 - val_accuracy: 0.2937
# Epoch 71/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.6100 - accuracy: 0.8021 - val_loss: 2.3827 - val_accuracy: 0.3438
# Epoch 72/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6433 - accuracy: 0.7875 - val_loss: 2.8333 - val_accuracy: 0.3187
# Epoch 73/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6296 - accuracy: 0.7885 - val_loss: 2.5655 - val_accuracy: 0.3938
# Epoch 74/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6756 - accuracy: 0.7677 - val_loss: 2.3991 - val_accuracy: 0.3875
# Epoch 75/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.5987 - accuracy: 0.7979 - val_loss: 2.4145 - val_accuracy: 0.3812
# Epoch 76/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5479 - accuracy: 0.8260 - val_loss: 2.6354 - val_accuracy: 0.3125
# Epoch 77/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.5872 - accuracy: 0.7969 - val_loss: 2.3514 - val_accuracy: 0.3562
# Epoch 78/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5757 - accuracy: 0.8031 - val_loss: 2.9513 - val_accuracy: 0.3000
# Epoch 79/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.5591 - accuracy: 0.8135 - val_loss: 2.7192 - val_accuracy: 0.3625
# Epoch 80/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5758 - accuracy: 0.8167 - val_loss: 2.5548 - val_accuracy: 0.3625
# Epoch 81/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6760 - accuracy: 0.7594 - val_loss: 2.5979 - val_accuracy: 0.3125
# Epoch 82/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.6934 - accuracy: 0.7594 - val_loss: 2.5802 - val_accuracy: 0.2688
# Epoch 83/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6147 - accuracy: 0.8031 - val_loss: 2.4759 - val_accuracy: 0.4250
# Epoch 84/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.4787 - accuracy: 0.8521 - val_loss: 3.0715 - val_accuracy: 0.3063
# Epoch 85/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5039 - accuracy: 0.8604 - val_loss: 2.2370 - val_accuracy: 0.4062
# Epoch 86/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.5034 - accuracy: 0.8302 - val_loss: 2.3716 - val_accuracy: 0.4437
# Epoch 87/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6249 - accuracy: 0.7885 - val_loss: 2.5880 - val_accuracy: 0.3688
# Epoch 88/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.6046 - accuracy: 0.7896 - val_loss: 2.6442 - val_accuracy: 0.4563
# Epoch 89/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5012 - accuracy: 0.8375 - val_loss: 2.4503 - val_accuracy: 0.3938
# Epoch 90/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5080 - accuracy: 0.8396 - val_loss: 2.5700 - val_accuracy: 0.3313
# Epoch 91/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.4784 - accuracy: 0.8427 - val_loss: 2.6943 - val_accuracy: 0.3750
# Epoch 92/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.5672 - accuracy: 0.8083 - val_loss: 3.5979 - val_accuracy: 0.2688
# Epoch 93/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5659 - accuracy: 0.8083 - val_loss: 2.3222 - val_accuracy: 0.3688
# Epoch 94/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5129 - accuracy: 0.8167 - val_loss: 3.3390 - val_accuracy: 0.2313
# Epoch 95/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4489 - accuracy: 0.8615 - val_loss: 2.9405 - val_accuracy: 0.3313
# Epoch 96/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.4603 - accuracy: 0.8385 - val_loss: 2.8545 - val_accuracy: 0.3438
# Epoch 97/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4200 - accuracy: 0.8687 - val_loss: 2.7810 - val_accuracy: 0.3688
# Epoch 98/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4498 - accuracy: 0.8521 - val_loss: 2.6868 - val_accuracy: 0.4250
# Epoch 99/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.4702 - accuracy: 0.8500 - val_loss: 2.9303 - val_accuracy: 0.3063
# Epoch 100/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.5466 - accuracy: 0.8052 - val_loss: 2.7096 - val_accuracy: 0.4062
# Epoch 101/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.4646 - accuracy: 0.8479 - val_loss: 2.5553 - val_accuracy: 0.3562
# Epoch 102/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4755 - accuracy: 0.8406 - val_loss: 2.9754 - val_accuracy: 0.2625
# Epoch 103/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4477 - accuracy: 0.8500 - val_loss: 3.1471 - val_accuracy: 0.3313
# Epoch 104/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3753 - accuracy: 0.8740 - val_loss: 3.1508 - val_accuracy: 0.3250
# Epoch 105/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.3916 - accuracy: 0.8719 - val_loss: 2.7005 - val_accuracy: 0.3375
# Epoch 106/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4635 - accuracy: 0.8365 - val_loss: 3.0462 - val_accuracy: 0.3250
# Epoch 107/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.3510 - accuracy: 0.8948 - val_loss: 3.3622 - val_accuracy: 0.2875
# Epoch 108/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3812 - accuracy: 0.8760 - val_loss: 2.8537 - val_accuracy: 0.4062
# Epoch 109/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3545 - accuracy: 0.8875 - val_loss: 3.1933 - val_accuracy: 0.3562
# Epoch 110/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3463 - accuracy: 0.8875 - val_loss: 2.7134 - val_accuracy: 0.4062
# Epoch 111/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3963 - accuracy: 0.8625 - val_loss: 2.8271 - val_accuracy: 0.4125
# Epoch 112/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4596 - accuracy: 0.8427 - val_loss: 2.8634 - val_accuracy: 0.3250
# Epoch 113/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3916 - accuracy: 0.8833 - val_loss: 2.7181 - val_accuracy: 0.3938
# Epoch 114/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3430 - accuracy: 0.8958 - val_loss: 3.2703 - val_accuracy: 0.3375
# Epoch 115/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3518 - accuracy: 0.8938 - val_loss: 2.9180 - val_accuracy: 0.4375
# Epoch 116/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3316 - accuracy: 0.9000 - val_loss: 3.0030 - val_accuracy: 0.4000
# Epoch 117/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3142 - accuracy: 0.8990 - val_loss: 2.8730 - val_accuracy: 0.3875
# Epoch 118/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4068 - accuracy: 0.8635 - val_loss: 3.0462 - val_accuracy: 0.3875
# Epoch 119/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3217 - accuracy: 0.8938 - val_loss: 2.7317 - val_accuracy: 0.3750
# Epoch 120/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2974 - accuracy: 0.9073 - val_loss: 3.1160 - val_accuracy: 0.3500
# Epoch 121/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3113 - accuracy: 0.9010 - val_loss: 3.3131 - val_accuracy: 0.2812
# Epoch 122/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4221 - accuracy: 0.8781 - val_loss: 3.0987 - val_accuracy: 0.2937
# Epoch 123/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4109 - accuracy: 0.8646 - val_loss: 3.7321 - val_accuracy: 0.3187
# Epoch 124/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4330 - accuracy: 0.8583 - val_loss: 3.3258 - val_accuracy: 0.3375
# Epoch 125/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3123 - accuracy: 0.8938 - val_loss: 2.6937 - val_accuracy: 0.4688
# Epoch 126/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3429 - accuracy: 0.8990 - val_loss: 3.1659 - val_accuracy: 0.4250
# Epoch 127/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.3382 - accuracy: 0.8990 - val_loss: 3.1422 - val_accuracy: 0.4062
# Epoch 128/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.3294 - accuracy: 0.8958 - val_loss: 3.2342 - val_accuracy: 0.3812
# Epoch 129/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.3246 - accuracy: 0.8979 - val_loss: 3.4260 - val_accuracy: 0.2875
# Epoch 130/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3232 - accuracy: 0.8938 - val_loss: 3.3820 - val_accuracy: 0.3313
# Epoch 131/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3949 - accuracy: 0.8750 - val_loss: 2.7549 - val_accuracy: 0.3187
# Epoch 132/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.3470 - accuracy: 0.8938 - val_loss: 3.3288 - val_accuracy: 0.3562
# Epoch 133/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2983 - accuracy: 0.9073 - val_loss: 3.0834 - val_accuracy: 0.3125
# Epoch 134/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2783 - accuracy: 0.9167 - val_loss: 2.9450 - val_accuracy: 0.3500
# Epoch 135/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2612 - accuracy: 0.9156 - val_loss: 2.8547 - val_accuracy: 0.3625
# Epoch 136/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2523 - accuracy: 0.9177 - val_loss: 3.0442 - val_accuracy: 0.3500
# Epoch 137/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3398 - accuracy: 0.8792 - val_loss: 3.1958 - val_accuracy: 0.3938
# Epoch 138/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3166 - accuracy: 0.8990 - val_loss: 3.7645 - val_accuracy: 0.2562
# Epoch 139/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2807 - accuracy: 0.9083 - val_loss: 3.3761 - val_accuracy: 0.3438
# Epoch 140/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2738 - accuracy: 0.9083 - val_loss: 3.8947 - val_accuracy: 0.3250
# Epoch 141/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3065 - accuracy: 0.9073 - val_loss: 3.1136 - val_accuracy: 0.3875
# Epoch 142/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3291 - accuracy: 0.9031 - val_loss: 3.8275 - val_accuracy: 0.3438
# Epoch 143/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3590 - accuracy: 0.8792 - val_loss: 3.6437 - val_accuracy: 0.2812
# Epoch 144/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2857 - accuracy: 0.9125 - val_loss: 3.0594 - val_accuracy: 0.3187
# Epoch 145/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2699 - accuracy: 0.9177 - val_loss: 3.3403 - val_accuracy: 0.3125
# Epoch 146/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1999 - accuracy: 0.9385 - val_loss: 3.0978 - val_accuracy: 0.3125
# Epoch 147/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2720 - accuracy: 0.9177 - val_loss: 3.7499 - val_accuracy: 0.2750
# Epoch 148/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2469 - accuracy: 0.9260 - val_loss: 3.5217 - val_accuracy: 0.3000
# Epoch 149/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3583 - accuracy: 0.8938 - val_loss: 3.4587 - val_accuracy: 0.3313
# Epoch 150/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2634 - accuracy: 0.9115 - val_loss: 3.7412 - val_accuracy: 0.3187
# Epoch 151/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2459 - accuracy: 0.9323 - val_loss: 3.5139 - val_accuracy: 0.3438
# Epoch 152/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2628 - accuracy: 0.9198 - val_loss: 3.3333 - val_accuracy: 0.3125
# Epoch 153/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2197 - accuracy: 0.9344 - val_loss: 3.6476 - val_accuracy: 0.2875
# Epoch 154/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1973 - accuracy: 0.9500 - val_loss: 3.4123 - val_accuracy: 0.3812
# Epoch 155/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2578 - accuracy: 0.9187 - val_loss: 4.3928 - val_accuracy: 0.2937
# Epoch 156/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.4438 - accuracy: 0.8573 - val_loss: 3.3527 - val_accuracy: 0.3688
# Epoch 157/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3468 - accuracy: 0.8750 - val_loss: 3.2791 - val_accuracy: 0.3750
# Epoch 158/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2052 - accuracy: 0.9354 - val_loss: 3.1828 - val_accuracy: 0.3812
# Epoch 159/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2283 - accuracy: 0.9281 - val_loss: 2.9968 - val_accuracy: 0.4500
# Epoch 160/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2563 - accuracy: 0.9281 - val_loss: 3.7031 - val_accuracy: 0.3438
# Epoch 161/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2521 - accuracy: 0.9219 - val_loss: 3.4805 - val_accuracy: 0.2812
# Epoch 162/300
# 30/30 [==============================] - 91s 3s/step - loss: 0.3009 - accuracy: 0.9000 - val_loss: 3.5628 - val_accuracy: 0.3812
# Epoch 163/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.3013 - accuracy: 0.9104 - val_loss: 3.5322 - val_accuracy: 0.3688
# Epoch 164/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2802 - accuracy: 0.9187 - val_loss: 3.7701 - val_accuracy: 0.3375
# Epoch 165/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2842 - accuracy: 0.9062 - val_loss: 3.7077 - val_accuracy: 0.3500
# Epoch 166/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.3213 - accuracy: 0.8969 - val_loss: 3.4586 - val_accuracy: 0.3500
# Epoch 167/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2645 - accuracy: 0.9208 - val_loss: 3.5524 - val_accuracy: 0.3187
# Epoch 168/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2999 - accuracy: 0.9156 - val_loss: 3.5450 - val_accuracy: 0.3688
# Epoch 169/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2800 - accuracy: 0.9000 - val_loss: 3.6672 - val_accuracy: 0.2875
# Epoch 170/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1969 - accuracy: 0.9333 - val_loss: 3.3917 - val_accuracy: 0.3750
# Epoch 171/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2273 - accuracy: 0.9323 - val_loss: 3.3539 - val_accuracy: 0.4000
# Epoch 172/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1961 - accuracy: 0.9396 - val_loss: 3.7182 - val_accuracy: 0.2937
# Epoch 173/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2439 - accuracy: 0.9208 - val_loss: 3.9936 - val_accuracy: 0.2937
# Epoch 174/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1970 - accuracy: 0.9344 - val_loss: 3.7193 - val_accuracy: 0.3063
# Epoch 175/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1636 - accuracy: 0.9500 - val_loss: 3.6988 - val_accuracy: 0.2438
# Epoch 176/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1854 - accuracy: 0.9417 - val_loss: 3.8324 - val_accuracy: 0.3125
# Epoch 177/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1957 - accuracy: 0.9417 - val_loss: 4.0682 - val_accuracy: 0.3375
# Epoch 178/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2094 - accuracy: 0.9385 - val_loss: 4.4202 - val_accuracy: 0.3562
# Epoch 179/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2365 - accuracy: 0.9260 - val_loss: 3.5626 - val_accuracy: 0.3875
# Epoch 180/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2350 - accuracy: 0.9365 - val_loss: 3.0539 - val_accuracy: 0.3875
# Epoch 181/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2277 - accuracy: 0.9292 - val_loss: 3.9786 - val_accuracy: 0.3125
# Epoch 182/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2133 - accuracy: 0.9375 - val_loss: 3.5275 - val_accuracy: 0.3688
# Epoch 183/300
# 30/30 [==============================] - 89s 3s/step - loss: 0.1771 - accuracy: 0.9438 - val_loss: 3.3947 - val_accuracy: 0.3375
# Epoch 184/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1676 - accuracy: 0.9490 - val_loss: 3.7663 - val_accuracy: 0.3688
# Epoch 185/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1808 - accuracy: 0.9490 - val_loss: 3.3848 - val_accuracy: 0.3875
# Epoch 186/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1641 - accuracy: 0.9594 - val_loss: 3.9161 - val_accuracy: 0.3063
# Epoch 187/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2426 - accuracy: 0.9292 - val_loss: 3.8135 - val_accuracy: 0.3625
# Epoch 188/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2015 - accuracy: 0.9427 - val_loss: 3.8436 - val_accuracy: 0.3187
# Epoch 189/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2214 - accuracy: 0.9333 - val_loss: 4.0167 - val_accuracy: 0.3187
# Epoch 190/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2546 - accuracy: 0.9125 - val_loss: 3.4684 - val_accuracy: 0.3938
# Epoch 191/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1854 - accuracy: 0.9385 - val_loss: 3.8305 - val_accuracy: 0.3313
# Epoch 192/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1843 - accuracy: 0.9365 - val_loss: 4.4379 - val_accuracy: 0.2562
# Epoch 193/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2370 - accuracy: 0.9385 - val_loss: 3.8121 - val_accuracy: 0.3250
# Epoch 194/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2114 - accuracy: 0.9354 - val_loss: 4.5806 - val_accuracy: 0.2625
# Epoch 195/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2022 - accuracy: 0.9375 - val_loss: 4.1726 - val_accuracy: 0.3125
# Epoch 196/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1903 - accuracy: 0.9406 - val_loss: 3.5918 - val_accuracy: 0.3438
# Epoch 197/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2235 - accuracy: 0.9333 - val_loss: 3.8012 - val_accuracy: 0.3938
# Epoch 198/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1906 - accuracy: 0.9427 - val_loss: 3.5375 - val_accuracy: 0.3812
# Epoch 199/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2053 - accuracy: 0.9323 - val_loss: 3.7051 - val_accuracy: 0.3562
# Epoch 200/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2045 - accuracy: 0.9365 - val_loss: 3.8727 - val_accuracy: 0.3125
# Epoch 201/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2054 - accuracy: 0.9396 - val_loss: 3.9174 - val_accuracy: 0.3812
# Epoch 202/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1674 - accuracy: 0.9521 - val_loss: 4.0229 - val_accuracy: 0.3250
# Epoch 203/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2852 - accuracy: 0.9062 - val_loss: 4.1942 - val_accuracy: 0.3375
# Epoch 204/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2990 - accuracy: 0.8948 - val_loss: 3.8738 - val_accuracy: 0.3750
# Epoch 205/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1971 - accuracy: 0.9469 - val_loss: 3.9558 - val_accuracy: 0.3063
# Epoch 206/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2017 - accuracy: 0.9406 - val_loss: 3.9617 - val_accuracy: 0.3187
# Epoch 207/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1763 - accuracy: 0.9510 - val_loss: 3.7875 - val_accuracy: 0.3438
# Epoch 208/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2127 - accuracy: 0.9427 - val_loss: 3.7822 - val_accuracy: 0.4125
# Epoch 209/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1781 - accuracy: 0.9469 - val_loss: 3.9367 - val_accuracy: 0.3375
# Epoch 210/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1997 - accuracy: 0.9438 - val_loss: 4.4724 - val_accuracy: 0.2375
# Epoch 211/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1470 - accuracy: 0.9552 - val_loss: 3.6040 - val_accuracy: 0.4000
# Epoch 212/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1463 - accuracy: 0.9583 - val_loss: 3.6001 - val_accuracy: 0.3625
# Epoch 213/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1897 - accuracy: 0.9438 - val_loss: 4.1634 - val_accuracy: 0.3500
# Epoch 214/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2274 - accuracy: 0.9312 - val_loss: 3.9975 - val_accuracy: 0.3000
# Epoch 215/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2002 - accuracy: 0.9406 - val_loss: 4.3237 - val_accuracy: 0.3187
# Epoch 216/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1740 - accuracy: 0.9427 - val_loss: 4.8654 - val_accuracy: 0.3375
# Epoch 217/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2131 - accuracy: 0.9354 - val_loss: 4.4907 - val_accuracy: 0.3375
# Epoch 218/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1975 - accuracy: 0.9354 - val_loss: 4.4009 - val_accuracy: 0.3438
# Epoch 219/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1494 - accuracy: 0.9510 - val_loss: 4.0689 - val_accuracy: 0.2875
# Epoch 220/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1306 - accuracy: 0.9677 - val_loss: 3.9636 - val_accuracy: 0.3187
# Epoch 221/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1447 - accuracy: 0.9552 - val_loss: 4.5556 - val_accuracy: 0.3375
# Epoch 222/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2115 - accuracy: 0.9292 - val_loss: 4.2083 - val_accuracy: 0.2937
# Epoch 223/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1554 - accuracy: 0.9552 - val_loss: 4.5665 - val_accuracy: 0.2812
# Epoch 224/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1646 - accuracy: 0.9438 - val_loss: 4.3010 - val_accuracy: 0.3625
# Epoch 225/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1682 - accuracy: 0.9510 - val_loss: 4.1801 - val_accuracy: 0.2500
# Epoch 226/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1487 - accuracy: 0.9573 - val_loss: 4.2137 - val_accuracy: 0.2937
# Epoch 227/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2808 - accuracy: 0.9062 - val_loss: 4.3138 - val_accuracy: 0.3812
# Epoch 228/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1616 - accuracy: 0.9500 - val_loss: 3.8616 - val_accuracy: 0.3688
# Epoch 229/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1639 - accuracy: 0.9583 - val_loss: 4.0272 - val_accuracy: 0.3500
# Epoch 230/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1418 - accuracy: 0.9604 - val_loss: 3.8451 - val_accuracy: 0.2875
# Epoch 231/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1783 - accuracy: 0.9375 - val_loss: 3.8543 - val_accuracy: 0.3187
# Epoch 232/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2336 - accuracy: 0.9167 - val_loss: 3.9390 - val_accuracy: 0.3500
# Epoch 233/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2289 - accuracy: 0.9312 - val_loss: 4.3107 - val_accuracy: 0.2750
# Epoch 234/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1931 - accuracy: 0.9458 - val_loss: 3.5475 - val_accuracy: 0.3500
# Epoch 235/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1557 - accuracy: 0.9510 - val_loss: 3.7975 - val_accuracy: 0.3562
# Epoch 236/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1089 - accuracy: 0.9667 - val_loss: 3.7494 - val_accuracy: 0.3500
# Epoch 237/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1091 - accuracy: 0.9677 - val_loss: 4.0084 - val_accuracy: 0.3250
# Epoch 238/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1354 - accuracy: 0.9583 - val_loss: 4.4459 - val_accuracy: 0.3313
# Epoch 239/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2544 - accuracy: 0.9177 - val_loss: 3.9430 - val_accuracy: 0.3625
# Epoch 240/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1758 - accuracy: 0.9479 - val_loss: 3.9331 - val_accuracy: 0.3313
# Epoch 241/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1638 - accuracy: 0.9500 - val_loss: 4.0659 - val_accuracy: 0.3250
# Epoch 242/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1428 - accuracy: 0.9531 - val_loss: 3.9512 - val_accuracy: 0.2625
# Epoch 243/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1417 - accuracy: 0.9594 - val_loss: 3.8406 - val_accuracy: 0.3125
# Epoch 244/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1824 - accuracy: 0.9385 - val_loss: 3.5231 - val_accuracy: 0.4000
# Epoch 245/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2106 - accuracy: 0.9281 - val_loss: 4.6669 - val_accuracy: 0.3438
# Epoch 246/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1721 - accuracy: 0.9417 - val_loss: 3.9082 - val_accuracy: 0.3438
# Epoch 247/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1458 - accuracy: 0.9604 - val_loss: 3.5723 - val_accuracy: 0.4062
# Epoch 248/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1236 - accuracy: 0.9604 - val_loss: 3.8108 - val_accuracy: 0.3625
# Epoch 249/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1310 - accuracy: 0.9646 - val_loss: 4.7389 - val_accuracy: 0.3562
# Epoch 250/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1145 - accuracy: 0.9708 - val_loss: 3.6776 - val_accuracy: 0.3812
# Epoch 251/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1184 - accuracy: 0.9740 - val_loss: 3.9636 - val_accuracy: 0.3625
# Epoch 252/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.0951 - accuracy: 0.9729 - val_loss: 3.7324 - val_accuracy: 0.2937
# Epoch 253/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1219 - accuracy: 0.9667 - val_loss: 4.1907 - val_accuracy: 0.2875
# Epoch 254/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1340 - accuracy: 0.9583 - val_loss: 4.1418 - val_accuracy: 0.2937
# Epoch 255/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1237 - accuracy: 0.9635 - val_loss: 4.2510 - val_accuracy: 0.3250
# Epoch 256/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1278 - accuracy: 0.9646 - val_loss: 4.3440 - val_accuracy: 0.3438
# Epoch 257/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2396 - accuracy: 0.9198 - val_loss: 4.4713 - val_accuracy: 0.2500
# Epoch 258/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2167 - accuracy: 0.9302 - val_loss: 4.4575 - val_accuracy: 0.2562
# Epoch 259/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1625 - accuracy: 0.9510 - val_loss: 3.7496 - val_accuracy: 0.4125
# Epoch 260/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1416 - accuracy: 0.9583 - val_loss: 4.0513 - val_accuracy: 0.3250
# Epoch 261/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1664 - accuracy: 0.9563 - val_loss: 3.6531 - val_accuracy: 0.2875
# Epoch 262/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.2009 - accuracy: 0.9438 - val_loss: 4.2215 - val_accuracy: 0.4125
# Epoch 263/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1754 - accuracy: 0.9500 - val_loss: 4.1686 - val_accuracy: 0.3688
# Epoch 264/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.0926 - accuracy: 0.9729 - val_loss: 3.7370 - val_accuracy: 0.3625
# Epoch 265/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1355 - accuracy: 0.9615 - val_loss: 4.1046 - val_accuracy: 0.3562
# Epoch 266/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1066 - accuracy: 0.9740 - val_loss: 4.0110 - val_accuracy: 0.3438
# Epoch 267/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1463 - accuracy: 0.9583 - val_loss: 4.3588 - val_accuracy: 0.3187
# Epoch 268/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1631 - accuracy: 0.9458 - val_loss: 4.4833 - val_accuracy: 0.2812
# Epoch 269/300
# 30/30 [==============================] - 89s 3s/step - loss: 0.1208 - accuracy: 0.9625 - val_loss: 3.9474 - val_accuracy: 0.2812
# Epoch 270/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1520 - accuracy: 0.9469 - val_loss: 4.3001 - val_accuracy: 0.2625
# Epoch 271/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1656 - accuracy: 0.9510 - val_loss: 4.4395 - val_accuracy: 0.2812
# Epoch 272/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2004 - accuracy: 0.9479 - val_loss: 4.2665 - val_accuracy: 0.3812
# Epoch 273/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1849 - accuracy: 0.9438 - val_loss: 4.6011 - val_accuracy: 0.2750
# Epoch 274/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1425 - accuracy: 0.9542 - val_loss: 4.2482 - val_accuracy: 0.3250
# Epoch 275/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1225 - accuracy: 0.9688 - val_loss: 3.8511 - val_accuracy: 0.3187
# Epoch 276/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1139 - accuracy: 0.9698 - val_loss: 3.8681 - val_accuracy: 0.3750
# Epoch 277/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1156 - accuracy: 0.9635 - val_loss: 4.5926 - val_accuracy: 0.3000
# Epoch 278/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2390 - accuracy: 0.9198 - val_loss: 6.0700 - val_accuracy: 0.2500
# Epoch 279/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1943 - accuracy: 0.9406 - val_loss: 4.4302 - val_accuracy: 0.3000
# Epoch 280/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.2184 - accuracy: 0.9187 - val_loss: 4.3171 - val_accuracy: 0.3250
# Epoch 281/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1485 - accuracy: 0.9500 - val_loss: 4.5566 - val_accuracy: 0.3000
# Epoch 282/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1447 - accuracy: 0.9531 - val_loss: 3.9144 - val_accuracy: 0.3562
# Epoch 283/300
# 30/30 [==============================] - 90s 3s/step - loss: 0.1260 - accuracy: 0.9542 - val_loss: 4.5183 - val_accuracy: 0.2812
# Epoch 284/300
# 30/30 [==============================] - 89s 3s/step - loss: 0.0880 - accuracy: 0.9802 - val_loss: 4.3371 - val_accuracy: 0.3500
# Epoch 285/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1081 - accuracy: 0.9615 - val_loss: 4.2412 - val_accuracy: 0.3187
# Epoch 286/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.0969 - accuracy: 0.9688 - val_loss: 4.6738 - val_accuracy: 0.3000
# Epoch 287/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1357 - accuracy: 0.9531 - val_loss: 4.3018 - val_accuracy: 0.3562
# Epoch 288/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.0896 - accuracy: 0.9708 - val_loss: 4.3147 - val_accuracy: 0.3250
# Epoch 289/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1554 - accuracy: 0.9542 - val_loss: 4.5329 - val_accuracy: 0.3250
# Epoch 290/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1213 - accuracy: 0.9646 - val_loss: 4.0442 - val_accuracy: 0.3938
# Epoch 291/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1291 - accuracy: 0.9625 - val_loss: 4.3783 - val_accuracy: 0.3313
# Epoch 292/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1115 - accuracy: 0.9646 - val_loss: 4.2440 - val_accuracy: 0.3562
# Epoch 293/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.0840 - accuracy: 0.9750 - val_loss: 4.1532 - val_accuracy: 0.3562
# Epoch 294/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.0778 - accuracy: 0.9771 - val_loss: 4.3697 - val_accuracy: 0.3125
# Epoch 295/300
# 30/30 [==============================] - 88s 3s/step - loss: 0.1172 - accuracy: 0.9635 - val_loss: 4.3486 - val_accuracy: 0.3688
# Epoch 296/300
# 30/30 [==============================] - 87s 3s/step - loss: 0.1990 - accuracy: 0.9385 - val_loss: 4.0540 - val_accuracy: 0.3875
# Epoch 297/300
# 30/30 [==============================] - 90s 3s/step - loss: 0.1921 - accuracy: 0.9417 - val_loss: 4.6562 - val_accuracy: 0.3000
# Epoch 298/300
# 30/30 [==============================] - 91s 3s/step - loss: 0.2266 - accuracy: 0.9333 - val_loss: 5.5206 - val_accuracy: 0.2750
# Epoch 299/300
# 30/30 [==============================] - 90s 3s/step - loss: 0.1564 - accuracy: 0.9510 - val_loss: 4.7014 - val_accuracy: 0.3625
# Epoch 300/300
# 30/30 [==============================] - 90s 3s/step - loss: 0.1617 - accuracy: 0.9542 - val_loss: 4.9012 - val_accuracy: 0.2500

# %% [markdown]
# ## Salvataggio parametri su file

# %%
filename = "3d_cnn_300.txt"  # Nome del file di destinazione

with open(filename, "w") as file:
    file.write("Image res: " + str(WIDTH) + "x" + str(HEIGHT) + "\n")
    file.write("Numero frames: " + str(n_frames) + "\n")
    file.write("Frame step: " + "3" + "\n")
    file.write("Batch size: " + str(batch_size) + "\n")
    file.write("Shuffle: " + "True" + "\n")
    file.write("Learning rate: Adam " + "(0.001)" + "\n")
    file.write("Spazial convolution: " + "7x7" + "\n")
    file.write("Time convolution: 3")

# %% [markdown]
# ## Visualizza i risultati
#
# Creare grafici della perdita e dell'accuratezza sui set di formazione e convalida:

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

plot_history(history)

# %% [markdown]
# # Valutare del modello
# Utilizzare Keras `model.evaluate` per ottenere la perdita e l'accuratezza sul set di dati di test.

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 5/5 [==============================] - 11s 2s/step - loss: 5.0862 - accuracy: 0.2625
# {'loss': 5.086214542388916, 'accuracy': 0.26249998807907104}

# %% [markdown]
# Per visualizzare ulteriormente le prestazioni del modello, utilizzare una matrice di confusione. La matrice di confusione consente di valutare le prestazioni del modello di classificazione oltre l'accuratezza. Per costruire la matrice di confusione per questo problema di classificazione multiclasse, ottenere i valori effettivi nel set di test e i valori previsti.

# %%
def get_actual_predicted_labels(dataset): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g')
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of babele for ' + ds_type)
  ax.set_xlabel('Predicted Action')
  ax.set_ylabel('Actual Action')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
fg = FrameGenerator(train_dir, n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# Rename the labels based on the provided mapping
label_mapping = {
    1: 'Italian',
    2: 'English',
    3: 'German',
    4: 'Spanish',
    5: 'Dutch',
    6: 'Russian',
    7: 'Japanese',
    8: 'French'
}

labels = [int(label) for label in labels]

renamed_labels = [label_mapping[label_id] for label_id in labels]

# Print the renamed labels
print(renamed_labels)
# Out:
# ['Italian', 'English', 'German', 'Spanish', 'Dutch', 'Russian', 'Japanese', 'French']

# %%
actual, predicted = get_actual_predicted_labels(train_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'training')
# Out:
# 30/30 [==============================] - 57s 2s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'test')
# Out:
# 5/5 [==============================] - 9s 2s/step

# %% [markdown]
# I valori di precision e recall per ogni classe possono anche essere calcolati utilizzando una matrice di confusione.

# %%
def calculate_classification_metrics(y_actual, y_pred, labels):
  """
    Calculate the precision and recall of a classification model using the ground truth and
    predicted values. 

    Args:
      y_actual: Ground truth labels.
      y_pred: Predicted labels.
      labels: List of classification labels.

    Return:
      Precision and recall measures.
  """
  cm = tf.math.confusion_matrix(y_actual, y_pred)
  tp = np.diag(cm) # Diagonal represents true positives
  precision = dict()
  recall = dict()
  for i in range(len(labels)):
    col = cm[:, i]
    fp = np.sum(col) - tp[i] # Sum of column minus true positive is false negative

    row = cm[i, :]
    fn = np.sum(row) - tp[i] # Sum of row minus true positive, is false negative

    precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision 

    recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

  return precision, recall

# %%
precision, recall = calculate_classification_metrics(actual, predicted, renamed_labels) # Test dataset

# %%
precision
# Out:
# {'Italian': 0.23076923076923078,
#  'English': 0.0625,
#  'German': 0.35,
#  'Spanish': 0.0,
#  'Dutch': 0.5454545454545454,
#  'Russian': 0.5263157894736842,
#  'Japanese': 0.5,
#  'French': 0.2}

# %%
recall
# Out:
# {'Italian': 0.6,
#  'English': 0.05,
#  'German': 0.35,
#  'Spanish': 0.0,
#  'Dutch': 0.3,
#  'Russian': 0.5,
#  'Japanese': 0.05,
#  'French': 0.25}

# %%
# Save the weights
model.save_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_3D/3dCNN_300_epoche/Pesi_Modello/pesi_3dcnn_300_epoche')

# Restore the weights
model.load_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_3D/3dCNN_300_epoche/Pesi_Modello/pesi_3dcnn_300_epoche')

model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.001), 
              metrics = ['accuracy'])

# Evaluate the model
loss, acc = model.evaluate(test_ds, verbose=2)
print("Modello caricato: accuracy: {:5.2f}%".format(100 * acc))
# Out:
# c:\Users\Vincenzo\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 5/5 - 11s - loss: 5.0010 - accuracy: 0.2500 - 11s/epoch - 2s/step
# Modello caricato: accuracy: 25.00%
