# %% [markdown]
# # Setup
# Inizia installando e importando alcune librerie necessarie, tra cui: `tqdm` per utilizzare una barra di avanzamento, `OpenCV` per elaborare file video, `einops` per eseguire operazioni tensoriali più complesse e `tensorflow_docs` per incorporare i dati in un notebook Jupyter.

# %%
# The way this tutorial uses the `TimeDistributed` layer requires TF>=2.10
# !pip install -U "tensorflow==2.10.0"
# !pip install -U "einops"
# Out:
# Requirement already satisfied: tensorflow==2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (23.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (49.2.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (4.6.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.54.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.19.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Requirement already satisfied: einops in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (0.6.1)

# %%
# !pip install tqdm opencv-python numpy matplotlib imageio seaborn
# !pip install tensorflow-docs
# Out:
# Requirement already satisfied: tqdm in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.65.0)
# Requirement already satisfied: opencv-python in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (3.7.1)
# Requirement already satisfied: imageio in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (2.29.0)
# Requirement already satisfied: seaborn in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (0.12.2)
# Requirement already satisfied: colorama in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tensorflow-docs in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (2023.5.26.9808)
# Requirement already satisfied: astor in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (0.8.1)
# Requirement already satisfied: absl-py in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (1.4.0)
# Requirement already satisfied: jinja2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (3.1.2)
# Requirement already satisfied: nbformat in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (5.8.0)
# Requirement already satisfied: protobuf>=3.12 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (3.19.6)
# Requirement already satisfied: pyyaml in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-docs) (6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from jinja2->tensorflow-docs) (2.1.2)
# Requirement already satisfied: fastjsonschema in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from nbformat->tensorflow-docs) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from nbformat->tensorflow-docs) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from nbformat->tensorflow-docs) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from nbformat->tensorflow-docs) (5.9.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat->tensorflow-docs) (0.19.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from jupyter-core->nbformat->tensorflow-docs) (3.5.1)
# Requirement already satisfied: pywin32>=300 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from jupyter-core->nbformat->tensorflow-docs) (306)

# %%
import seaborn as sns

import tqdm
import random
import pathlib
import itertools
import collections

import os
import cv2
import numpy as np

import tensorflow as tf

import shutil #roba fresca aggiunta da poco
import matplotlib.pyplot as plt 

# Some modules to display an animation using imageio.
import imageio
from IPython import display
from urllib import request
from tensorflow_docs.vis import embed

import keras
from keras import layers
import einops

# %% [markdown]
# # Fase di Pre-processing
# Si noti che il nome della classe è incluso nel nome del file di ogni video.
#
# Definire la funzione `get_class` che recupera il nome della classe da un nome di file. Quindi, creare una funzione chiamata `get_files_per_class` che converte l'elenco di tutti i file (file sopra) in un dizionario che elenca i file per ogni classe:

# %%
def get_class(fname):
  """ Retrieve the name of the class given a filename.

    Args:
      fname: Name of the file in the UCF101 dataset.

    Returns:
      Class that the file belongs to.
  """
  return fname.split('_')[-7]

# %%
def get_files_per_class(files):
  """ Retrieve the files that belong to each class.

    Args:
      files: List of files in the dataset.

    Returns:
      Dictionary of class names (key) and files (values). 
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %% [markdown]
# Il seguente blocco serve per contare i file video di tipo `*.avi `in tutte le sottocartelle del dataset

# %%
download_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val")

video_count_train = len(list(download_dir.glob('Train/*/*.avi')))
video_count_val = len(list(download_dir.glob('Validation/*/*.avi')))
video_count_test = len(list(download_dir.glob('Test/*/*.avi')))
video_total = video_count_train + video_count_val + video_count_test

print(f"print_train: {video_count_train}")
print(f"print_val: {video_count_val}")
print(f"print_test: {video_count_test}")
print(f"Total videos: {video_total}")
# Out:
# Total videos: 1280

# %% [markdown]
# # Crea fotogrammi da ogni file video

# %% [markdown]
# La funzione `frames_from_video_file` divide i video in frame, legge un intervallo scelto a caso di `n_frame` da un file video e li restituisce come `array` NumPy. Per ridurre la memoria e il sovraccarico di calcolo, scegliere un piccolo numero di fotogrammi. Inoltre, scegli lo stesso numero di fotogrammi da ogni video, il che rende più facile lavorare su lotti di dati.

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.
    
    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

# %%
def frames_from_video_file(video_path, n_frames, output_size = (60,90), frame_step = 3):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))  

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

# %% [markdown]
# # Visualizza i dati video

# %% [markdown]
# Snippet di
# codice per fare un gif dato un video preso a caso nella cartella di Train

# %%
def to_gif(images):
  converted_images = np.clip(images * 255, 0, 255).astype(np.uint8)
  imageio.mimsave('./animation.gif', converted_images, duration=125)
  return embed.embed_file('./animation.gif')

# docs-infra: no-execute
ucf_sample_video = frames_from_video_file(next(download_dir.glob('Train/*/*.avi')), 80)
to_gif(ucf_sample_video)
# Out:
# <img src="data:image/gif;base64,..."/>

# %% [markdown]
# Successivamente, definire la classe `FrameGenerator` per creare un oggetto iterabile in grado di immettere dati nella pipeline di dati TensorFlow. La funzione generatore `(__call__)` produce l'array di frame prodotto da `frames_from_video_file` e un vettore codificato one-hot dell'etichetta associata all'insieme di frame.

# %%
class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.avi'))
    classes = [p.parent.name for p in video_paths] 
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames) 
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %% [markdown]
# Creiamo il training, il  validation e il test sets (train_ds, val_ds, test_ds).

# %%
n_frames = 40
batch_size = 32

train_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Train")
test_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Test")
val_dir = pathlib.Path("C:/Users/Vincenzo/Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Validation")

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_ds = tf.data.Dataset.from_generator(FrameGenerator(train_dir, n_frames, training=True),
                                          output_signature = output_signature)


# Batch the data
train_ds = train_ds.batch(batch_size)

val_ds = tf.data.Dataset.from_generator(FrameGenerator(val_dir, n_frames),
                                        output_signature = output_signature)
val_ds = val_ds.batch(batch_size)

test_ds = tf.data.Dataset.from_generator(FrameGenerator(test_dir, n_frames),
                                         output_signature = output_signature)
test_ds = test_ds.batch(batch_size)

# %% [markdown]
# # Creazione del modello

# %% [markdown]
# Il seguente modello di rete neurale convoluzionale 3D si basa sul documento A Closer Look at Spatiotemporal Convolutions for Action Recognition di D. Tran et al. (2017). Il documento confronta diverse versioni di 3D ResNets. Invece di operare su una singola immagine con dimensioni `(altezza, larghezza)`, come le ResNet standard, queste operano sul volume video `(tempo, altezza, larghezza)`. L'approccio più ovvio a questo problema sarebbe sostituire ogni convoluzione 2D `(layers.Conv2D)` con una convoluzione 3D `(layers.Conv3D)`.
#
# Questo progetto utilizza una convoluzione (2 + 1)D con connessioni residue. La convoluzione (2 + 1)D consente la decomposizione delle dimensioni spaziali e temporali, creando quindi due passaggi separati. Un vantaggio di questo approccio è che la fattorizzazione delle convoluzioni in dimensioni spaziali e temporali salva i parametri.
#
# Per ogni posizione di uscita una convoluzione 3D combina tutti i vettori da una patch 3D del volume per creare un vettore nel volume di uscita.
# ![3DCNN.png](data:image/png;base64,...)
#
# Questa operazione richiede `time * height * width * channels` inputs e produce `channels` uscite (supponendo che il numero di canali di ingresso e di uscita siano gli stessi. Quindi un livello di convoluzione 3D con una dimensione del kernel di `(3 x 3 x 3)` avrebbe bisogno di una matrice di peso con `27 * channels ** 2` voci. Il documento di riferimento ha rilevato che un approccio più efficace ed efficiente era quello di fattorizzare la convoluzione. Invece di una singola convoluzione 3D per elaborare le dimensioni del tempo e dello spazio, hanno proposto una convoluzione "(2+1)D" che elabora le dimensioni dello spazio e del tempo separatamente. La figura seguente mostra le convoluzioni spaziali e temporali fattorizzate di una convoluzione (2 + 1)D.
# ![2plus1CNN.png](data:image/png;base64,...)
#
# Il vantaggio principale di questo approccio è che riduce il numero di parametri. Nella convoluzione (2 + 1)D la convoluzione spaziale prende i dati della forma `(1, width, height)`, mentre la convoluzione temporale prende i dati della forma `(time, 1, 1)`. Ad esempio, una convoluzione (2 + 1)D con dimensioni del kernel `(3 x 3 x 3)` avrebbe bisogno di matrici di peso di dimensioni `(9 * channels **2) + (3 * channels **2),` meno della metà della convoluzione 3D completa. Questo progetto implementa (2 + 1)D ResNet18, in cui ogni convoluzione nella resnet è sostituita da una convoluzione (2+1)D.

# %%
# Define the dimensions of one frame in the set of frames created
HEIGHT = 60
WIDTH = 90

# %%
class Conv2Plus1D(keras.layers.Layer):
  def __init__(self, filters, kernel_size, padding):
    """
      A sequence of convolutional layers that first apply the convolution operation over the
      spatial dimensions, and then the temporal dimension. 
    """
    super().__init__()
    self.seq = keras.Sequential([  
        # Spatial decomposition
        layers.Conv3D(filters=filters,
                      kernel_size=(1, kernel_size[1], kernel_size[2]),
                      padding=padding),
        # Temporal decomposition
        layers.Conv3D(filters=filters, 
                      kernel_size=(kernel_size[0], 1, 1),
                      padding=padding)
        ])

  def call(self, x):
    return self.seq(x)

# %% [markdown]
# Un modello ResNet resnet è costituito da una sequenza di blocchi residui. Un blocco residuo ha due rami. Il ramo principale esegue la calculatoion, ma è difficile per i gradienti passare attraverso. Il ramo residuo bypassa il calcolo principale e per lo più aggiunge solo l'input all'output del ramo principale. I gradienti scorrono facilmente attraverso questo ramo. Pertanto, sarà presente un percorso facile dalla funzione di perdita a uno qualsiasi dei rami principali del blocco residuo. Questo evita il problema del gradiente di fuga.
#
# Creare il ramo principale del blocco residuo con la seguente classe. A differenza della struttura ResNet standard, questo utilizza il layer Conv2Plus1D personalizzato invece di layers.Conv2D.

# %%
class ResidualMain(keras.layers.Layer):
  """
    Residual block of the model with convolution, layer normalization, and the
    activation function, ReLU.
  """
  def __init__(self, filters, kernel_size):
    super().__init__()
    self.seq = keras.Sequential([
        Conv2Plus1D(filters=filters,
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization(),
        layers.ReLU(),
        Conv2Plus1D(filters=filters, 
                    kernel_size=kernel_size,
                    padding='same'),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %% [markdown]
# Per aggiungere il ramo residuo al ramo principale deve avere le stesse dimensioni. Il livello di progetto riportato di seguito si occupa dei casi in cui il numero di canali viene modificato sul ramo. In particolare, viene aggiunta una sequenza di strato densamente connesso seguito dalla normalizzazione.

# %%
class Project(keras.layers.Layer):
  """
    Project certain dimensions of the tensor as the data is passed through different 
    sized filters and downsampled. 
  """
  def __init__(self, units):
    super().__init__()
    self.seq = keras.Sequential([
        layers.Dense(units),
        layers.LayerNormalization()
    ])

  def call(self, x):
    return self.seq(x)

# %% [markdown]
# Utilizzare `add_residual_block` per introdurre una connessione skip tra i layer del modello.

# %%
def add_residual_block(input, filters, kernel_size):
  """
    Add residual blocks to the model. If the last dimensions of the input data
    and filter size does not match, project it such that last dimension matches.
  """
  out = ResidualMain(filters, 
                     kernel_size)(input)

  res = input
  # Using the Keras functional APIs, project the last dimension of the tensor to
  # match the new filter size
  if out.shape[-1] != input.shape[-1]:
    res = Project(out.shape[-1])(res)

  return layers.add([res, out])

# %% [markdown]
# Il ridimensionamento del video è necessario per eseguire il downsampling dei dati. In particolare, il downsampling dei fotogrammi video consente al modello di esaminare parti specifiche dei fotogrammi per rilevare modelli che possono essere specifici per una determinata azione. Attraverso il downsampling, le informazioni non essenziali possono essere scartate. Inoltre, il ridimensionamento del video consentirà una riduzione della dimensionalità e quindi un'elaborazione più rapida attraverso il modello.

# %%
class ResizeVideo(keras.layers.Layer):
  def __init__(self, height, width):
    super().__init__()
    self.height = height
    self.width = width
    self.resizing_layer = layers.Resizing(self.height, self.width)

  def call(self, video):
    """
      Use the einops library to resize the tensor.  

      Args:
        video: Tensor representation of the video, in the form of a set of frames.

      Return:
        A downsampled size of the video according to the new height and width it should be resized to.
    """
    # b stands for batch size, t stands for time, h stands for height, 
    # w stands for width, and c stands for the number of channels.
    old_shape = einops.parse_shape(video, 'b t h w c')
    images = einops.rearrange(video, 'b t h w c -> (b t) h w c')
    images = self.resizing_layer(images)
    videos = einops.rearrange(
        images, '(b t) h w c -> b t h w c',
        t = old_shape['t'])
    return videos

# %% [markdown]
# Uso l'API Funtion di Keras per costruire la rete residua.

# %%
input_shape = (None, n_frames, HEIGHT, WIDTH, 3)
input = layers.Input(shape=(input_shape[1:]))
x = input

x = Conv2Plus1D(filters=16, kernel_size=(3, 7, 7), padding='same')(x)
x = layers.BatchNormalization()(x)
x = layers.ReLU()(x)
x = ResizeVideo(HEIGHT // 2, WIDTH // 2)(x)

# Block 1
x = add_residual_block(x, 8, (3, 3, 3))
x = ResizeVideo(HEIGHT // 4, WIDTH // 4)(x)

# Block 2
x = add_residual_block(x, 16, (3, 3, 3))
x = ResizeVideo(HEIGHT // 8, WIDTH // 8)(x)

# Block 3
x = add_residual_block(x, 32, (3, 3, 3))
x = ResizeVideo(HEIGHT // 16, WIDTH // 16)(x)

# Block 4
x = add_residual_block(x, 64, (3, 3, 3))

x = layers.GlobalAveragePooling3D()(x)

x = layers.Flatten()(x)

x = layers.Dropout(0.5)(x)

x = layers.Dense(8, activation='softmax')(x)

model = keras.Model(input, x)

# %%
frames, label = next(iter(train_ds))
model.build(frames)

# %% [markdown]
# ## Traino il modello

# %% [markdown]
# Per questo progetto, è stato scelto l'ottimizzatore `tf.keras.optimizers.Adam` e la funzione di loss `tf.keras.losses.SparseCategoricalCrossentropy` che è indicata per i modelli multi-classe. Utilizzare l'argomento delle metriche per visualizzare l'accuratezza delle prestazioni del modello in ogni fase.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 40, 60, 90,  0           []
#                                  3)]
#
#  conv2_plus1d (Conv2Plus1D)     (None, 40, 60, 90,   3152        ['input_1[0][0]']
#                                 16)
#
#  batch_normalization (BatchNorm  (None, 40, 60, 90,   64         ['conv2_plus1d[0][0]']
#  alization)                     16)
#
#  re_lu (ReLU)                   (None, 40, 60, 90,   0           ['batch_normalization[0][0]']
#                                 16)
#
#  resize_video (ResizeVideo)     (None, 40, 30, 45,   0           ['re_lu[0][0]']
#                                 16)
#
#  project (Project)              (None, 40, 30, 45,   152         ['resize_video[0][0]']
#                                 8)
#
#  residual_main (ResidualMain)   (None, 40, 30, 45,   2176        ['resize_video[0][0]']
#                                 8)
#
#  add (Add)                      (None, 40, 30, 45,   0           ['project[0][0]',
#                                 8)                                'residual_main[0][0]']
#
#  resize_video_1 (ResizeVideo)   (None, 40, 15, 22,   0           ['add[0][0]']
#                                 8)
#
#  project_1 (Project)            (None, 40, 15, 22,   176         ['resize_video_1[0][0]']
#                                 16)
#
#  residual_main_1 (ResidualMain)  (None, 40, 15, 22,   5120       ['resize_video_1[0][0]']
#                                 16)
#
#  add_1 (Add)                    (None, 40, 15, 22,   0           ['project_1[0][0]',
#                                 16)                               'residual_main_1[0][0]']
#
#  resize_video_2 (ResizeVideo)   (None, 40, 7, 11, 1  0           ['add_1[0][0]']
#                                 6)
#
#  project_2 (Project)            (None, 40, 7, 11, 3  608         ['resize_video_2[0][0]']
#                                 2)
#
#  residual_main_2 (ResidualMain)  (None, 40, 7, 11, 3  20224      ['resize_video_2[0][0]']
#                                 2)
#
#  add_2 (Add)                    (None, 40, 7, 11, 3  0           ['project_2[0][0]',
#                                 2)                                'residual_main_2[0][0]']
#
#  resize_video_3 (ResizeVideo)   (None, 40, 3, 5, 32  0           ['add_2[0][0]']
#                                 )
#
#  project_3 (Project)            (None, 40, 3, 5, 64  2240        ['resize_video_3[0][0]']
#                                 )
#
#  residual_main_3 (ResidualMain)  (None, 40, 3, 5, 64  80384      ['resize_video_3[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 40, 3, 5, 64  0           ['project_3[0][0]',
#                                 )                                 'residual_main_3[0][0]']
#
#  global_average_pooling3d (Glob  (None, 64)          0           ['add_3[0][0]']
#  alAveragePooling3D)
#
#  flatten (Flatten)              (None, 64)           0           ['global_average_pooling3d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 64)           0           ['flatten[0][0]']
#
#  dense_4 (Dense)                (None, 8)            520         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 114,816
# Trainable params: 114,784
# Non-trainable params: 32
# __________________________________________________________________________________________________

# %%
model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.001), 
              metrics = ['accuracy'])

# %% [markdown]
# Addestra il modello per 10 epoche con il metodo Keras `model.fit`.

# %%
history = model.fit(x = train_ds,
                    epochs = 150,
                    shuffle= True,
                    validation_data = val_ds)
# Out:
# Epoch 1/150
# c:\Users\Vincenzo\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 30/30 [==============================] - 453s 15s/step - loss: 2.6040 - accuracy: 0.1833 - val_loss: 2.3998 - val_accuracy: 0.1250
# Epoch 2/150
# 30/30 [==============================] - 405s 14s/step - loss: 2.1278 - accuracy: 0.1833 - val_loss: 2.1210 - val_accuracy: 0.1813
# Epoch 3/150
# 30/30 [==============================] - 407s 14s/step - loss: 2.1025 - accuracy: 0.1906 - val_loss: 2.3230 - val_accuracy: 0.1063
# Epoch 4/150
# 30/30 [==============================] - 408s 14s/step - loss: 2.0397 - accuracy: 0.2083 - val_loss: 2.2279 - val_accuracy: 0.1500
# Epoch 5/150
# 30/30 [==============================] - 430s 14s/step - loss: 1.9265 - accuracy: 0.2698 - val_loss: 2.1813 - val_accuracy: 0.1625
# Epoch 6/150
# 30/30 [==============================] - 445s 15s/step - loss: 1.9182 - accuracy: 0.2646 - val_loss: 2.3912 - val_accuracy: 0.1688
# Epoch 7/150
# 30/30 [==============================] - 438s 15s/step - loss: 1.8582 - accuracy: 0.2906 - val_loss: 2.0554 - val_accuracy: 0.2313
# Epoch 8/150
# 30/30 [==============================] - 419s 14s/step - loss: 1.8050 - accuracy: 0.3187 - val_loss: 1.9538 - val_accuracy: 0.3375
# Epoch 9/150
# 30/30 [==============================] - 413s 14s/step - loss: 1.7626 - accuracy: 0.3167 - val_loss: 2.2010 - val_accuracy: 0.2562
# Epoch 10/150
# 30/30 [==============================] - 410s 14s/step - loss: 1.7253 - accuracy: 0.3333 - val_loss: 2.0077 - val_accuracy: 0.2000
# Epoch 11/150
# 30/30 [==============================] - 412s 14s/step - loss: 1.6954 - accuracy: 0.3479 - val_loss: 2.2464 - val_accuracy: 0.2125
# Epoch 12/150
# 30/30 [==============================] - 422s 14s/step - loss: 1.7060 - accuracy: 0.3490 - val_loss: 2.1422 - val_accuracy: 0.2688
# Epoch 13/150
# 30/30 [==============================] - 423s 14s/step - loss: 1.5877 - accuracy: 0.3990 - val_loss: 1.9987 - val_accuracy: 0.2688
# Epoch 14/150
# 30/30 [==============================] - 420s 14s/step - loss: 1.5365 - accuracy: 0.4115 - val_loss: 2.2775 - val_accuracy: 0.2688
# Epoch 15/150
# 30/30 [==============================] - 422s 14s/step - loss: 1.5303 - accuracy: 0.4125 - val_loss: 2.3459 - val_accuracy: 0.2500
# Epoch 16/150
# 30/30 [==============================] - 425s 14s/step - loss: 1.5070 - accuracy: 0.4260 - val_loss: 1.9395 - val_accuracy: 0.2937
# Epoch 17/150
# 30/30 [==============================] - 418s 14s/step - loss: 1.4103 - accuracy: 0.4708 - val_loss: 2.2219 - val_accuracy: 0.1625
# Epoch 18/150
# 30/30 [==============================] - 419s 14s/step - loss: 1.3243 - accuracy: 0.5010 - val_loss: 1.8170 - val_accuracy: 0.2937
# Epoch 19/150
# 30/30 [==============================] - 417s 14s/step - loss: 1.2783 - accuracy: 0.5198 - val_loss: 1.8235 - val_accuracy: 0.3375
# Epoch 20/150
# 30/30 [==============================] - 417s 14s/step - loss: 1.2030 - accuracy: 0.5490 - val_loss: 2.2494 - val_accuracy: 0.3875
# Epoch 21/150
# 30/30 [==============================] - 418s 14s/step - loss: 1.1353 - accuracy: 0.5781 - val_loss: 2.0025 - val_accuracy: 0.3187
# Epoch 22/150
# 30/30 [==============================] - 417s 14s/step - loss: 1.1074 - accuracy: 0.5990 - val_loss: 2.6108 - val_accuracy: 0.2062
# Epoch 23/150
# 30/30 [==============================] - 416s 14s/step - loss: 1.0593 - accuracy: 0.5938 - val_loss: 2.2375 - val_accuracy: 0.1937
# Epoch 24/150
# 30/30 [==============================] - 417s 14s/step - loss: 1.0562 - accuracy: 0.6104 - val_loss: 2.3953 - val_accuracy: 0.3187
# Epoch 25/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.9507 - accuracy: 0.6719 - val_loss: 1.9162 - val_accuracy: 0.4125
# Epoch 26/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.9185 - accuracy: 0.6656 - val_loss: 2.7796 - val_accuracy: 0.2188
# Epoch 27/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.9320 - accuracy: 0.6687 - val_loss: 2.1204 - val_accuracy: 0.3375
# Epoch 28/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.7558 - accuracy: 0.7396 - val_loss: 2.0762 - val_accuracy: 0.4125
# Epoch 29/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.8125 - accuracy: 0.7135 - val_loss: 2.6111 - val_accuracy: 0.2875
# Epoch 30/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.7154 - accuracy: 0.7490 - val_loss: 2.1212 - val_accuracy: 0.3562
# Epoch 31/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.6700 - accuracy: 0.7594 - val_loss: 2.3281 - val_accuracy: 0.2875
# Epoch 32/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.5761 - accuracy: 0.8146 - val_loss: 2.4042 - val_accuracy: 0.3625
# Epoch 33/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.5602 - accuracy: 0.8208 - val_loss: 2.9847 - val_accuracy: 0.2062
# Epoch 34/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.5208 - accuracy: 0.8104 - val_loss: 1.9795 - val_accuracy: 0.3562
# Epoch 35/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.4847 - accuracy: 0.8417 - val_loss: 2.9239 - val_accuracy: 0.2188
# Epoch 36/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.6023 - accuracy: 0.7906 - val_loss: 3.1014 - val_accuracy: 0.3125
# Epoch 37/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.5051 - accuracy: 0.8229 - val_loss: 2.5853 - val_accuracy: 0.3000
# Epoch 38/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.4567 - accuracy: 0.8510 - val_loss: 2.0887 - val_accuracy: 0.4250
# Epoch 39/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.4080 - accuracy: 0.8708 - val_loss: 2.5457 - val_accuracy: 0.2875
# Epoch 40/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.4243 - accuracy: 0.8583 - val_loss: 2.3312 - val_accuracy: 0.3500
# Epoch 41/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.4001 - accuracy: 0.8781 - val_loss: 2.8592 - val_accuracy: 0.2750
# Epoch 42/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.3686 - accuracy: 0.8896 - val_loss: 3.1119 - val_accuracy: 0.3438
# Epoch 43/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.3356 - accuracy: 0.8917 - val_loss: 3.2830 - val_accuracy: 0.2375
# Epoch 44/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.2824 - accuracy: 0.9073 - val_loss: 2.7522 - val_accuracy: 0.3187
# Epoch 45/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.3350 - accuracy: 0.9010 - val_loss: 2.4704 - val_accuracy: 0.3812
# Epoch 46/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.2717 - accuracy: 0.9167 - val_loss: 3.4205 - val_accuracy: 0.2500
# Epoch 47/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.1842 - accuracy: 0.9500 - val_loss: 2.2836 - val_accuracy: 0.3812
# Epoch 48/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.2217 - accuracy: 0.9281 - val_loss: 2.8069 - val_accuracy: 0.3063
# Epoch 49/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.2128 - accuracy: 0.9323 - val_loss: 3.0604 - val_accuracy: 0.3750
# Epoch 50/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.2727 - accuracy: 0.9135 - val_loss: 3.0599 - val_accuracy: 0.2188
# Epoch 51/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.3023 - accuracy: 0.9062 - val_loss: 3.3281 - val_accuracy: 0.3438
# Epoch 52/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.2885 - accuracy: 0.8917 - val_loss: 2.4280 - val_accuracy: 0.3688
# Epoch 53/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.2364 - accuracy: 0.9292 - val_loss: 2.7943 - val_accuracy: 0.3250
# Epoch 54/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.1703 - accuracy: 0.9521 - val_loss: 2.2887 - val_accuracy: 0.4250
# Epoch 55/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.1399 - accuracy: 0.9594 - val_loss: 2.4810 - val_accuracy: 0.4313
# Epoch 56/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.1329 - accuracy: 0.9646 - val_loss: 2.6372 - val_accuracy: 0.3250
# Epoch 57/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1360 - accuracy: 0.9583 - val_loss: 3.2013 - val_accuracy: 0.3375
# Epoch 58/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0927 - accuracy: 0.9771 - val_loss: 3.3254 - val_accuracy: 0.3063
# Epoch 59/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0955 - accuracy: 0.9792 - val_loss: 2.8325 - val_accuracy: 0.3063
# Epoch 60/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.1001 - accuracy: 0.9750 - val_loss: 3.0669 - val_accuracy: 0.3750
# Epoch 61/150
# 30/30 [==============================] - 422s 14s/step - loss: 0.0960 - accuracy: 0.9771 - val_loss: 2.7913 - val_accuracy: 0.3875
# Epoch 62/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0731 - accuracy: 0.9833 - val_loss: 2.7606 - val_accuracy: 0.4062
# Epoch 63/150
# 30/30 [==============================] - 431s 14s/step - loss: 0.0790 - accuracy: 0.9781 - val_loss: 2.9183 - val_accuracy: 0.3688
# Epoch 64/150
# 30/30 [==============================] - 428s 14s/step - loss: 0.1277 - accuracy: 0.9688 - val_loss: 3.5349 - val_accuracy: 0.2812
# Epoch 65/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.2503 - accuracy: 0.9156 - val_loss: 2.8166 - val_accuracy: 0.4250
# Epoch 66/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1705 - accuracy: 0.9458 - val_loss: 3.4709 - val_accuracy: 0.3625
# Epoch 67/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1736 - accuracy: 0.9490 - val_loss: 3.4471 - val_accuracy: 0.3938
# Epoch 68/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1922 - accuracy: 0.9458 - val_loss: 3.7171 - val_accuracy: 0.3250
# Epoch 69/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1515 - accuracy: 0.9552 - val_loss: 3.4894 - val_accuracy: 0.3063
# Epoch 70/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1235 - accuracy: 0.9625 - val_loss: 3.2780 - val_accuracy: 0.4375
# Epoch 71/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1424 - accuracy: 0.9563 - val_loss: 3.1265 - val_accuracy: 0.3187
# Epoch 72/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.2014 - accuracy: 0.9365 - val_loss: 3.0490 - val_accuracy: 0.3625
# Epoch 73/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1244 - accuracy: 0.9646 - val_loss: 3.1869 - val_accuracy: 0.3187
# Epoch 74/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1132 - accuracy: 0.9688 - val_loss: 3.3842 - val_accuracy: 0.2750
# Epoch 75/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0505 - accuracy: 0.9885 - val_loss: 3.0849 - val_accuracy: 0.3625
# Epoch 76/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0559 - accuracy: 0.9854 - val_loss: 2.6886 - val_accuracy: 0.4062
# Epoch 77/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0411 - accuracy: 0.9906 - val_loss: 2.6826 - val_accuracy: 0.3812
# Epoch 78/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0303 - accuracy: 0.9937 - val_loss: 3.8642 - val_accuracy: 0.3125
# Epoch 79/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0457 - accuracy: 0.9906 - val_loss: 3.1782 - val_accuracy: 0.3625
# Epoch 80/150
# 30/30 [==============================] - 416s 14s/step - loss: 0.0575 - accuracy: 0.9812 - val_loss: 3.7858 - val_accuracy: 0.3063
# Epoch 81/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0847 - accuracy: 0.9740 - val_loss: 2.8768 - val_accuracy: 0.4062
# Epoch 82/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1003 - accuracy: 0.9656 - val_loss: 3.0838 - val_accuracy: 0.4000
# Epoch 83/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.0705 - accuracy: 0.9760 - val_loss: 3.4384 - val_accuracy: 0.2562
# Epoch 84/150
# 30/30 [==============================] - 422s 14s/step - loss: 0.0869 - accuracy: 0.9750 - val_loss: 3.3032 - val_accuracy: 0.3438
# Epoch 85/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.1425 - accuracy: 0.9552 - val_loss: 3.5483 - val_accuracy: 0.3625
# Epoch 86/150
# 30/30 [==============================] - 423s 14s/step - loss: 0.1763 - accuracy: 0.9490 - val_loss: 3.9675 - val_accuracy: 0.3187
# Epoch 87/150
# 30/30 [==============================] - 426s 14s/step - loss: 0.0979 - accuracy: 0.9719 - val_loss: 3.5224 - val_accuracy: 0.3438
# Epoch 88/150
# 30/30 [==============================] - 439s 15s/step - loss: 0.0965 - accuracy: 0.9729 - val_loss: 3.4784 - val_accuracy: 0.4313
# Epoch 89/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0733 - accuracy: 0.9750 - val_loss: 3.8354 - val_accuracy: 0.4062
# Epoch 90/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0723 - accuracy: 0.9792 - val_loss: 3.0977 - val_accuracy: 0.3562
# Epoch 91/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0575 - accuracy: 0.9823 - val_loss: 3.6116 - val_accuracy: 0.3438
# Epoch 92/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0701 - accuracy: 0.9844 - val_loss: 4.6204 - val_accuracy: 0.3313
# Epoch 93/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0724 - accuracy: 0.9750 - val_loss: 3.5712 - val_accuracy: 0.3438
# Epoch 94/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0822 - accuracy: 0.9750 - val_loss: 3.8856 - val_accuracy: 0.3812
# Epoch 95/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0936 - accuracy: 0.9688 - val_loss: 3.4956 - val_accuracy: 0.4375
# Epoch 96/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.0905 - accuracy: 0.9771 - val_loss: 3.6023 - val_accuracy: 0.3812
# Epoch 97/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0934 - accuracy: 0.9677 - val_loss: 3.6091 - val_accuracy: 0.4250
# Epoch 98/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.2163 - accuracy: 0.9458 - val_loss: 4.1559 - val_accuracy: 0.3125
# Epoch 99/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1030 - accuracy: 0.9677 - val_loss: 3.5797 - val_accuracy: 0.3750
# Epoch 100/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0838 - accuracy: 0.9729 - val_loss: 3.5992 - val_accuracy: 0.2188
# Epoch 101/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1224 - accuracy: 0.9604 - val_loss: 3.8637 - val_accuracy: 0.3125
# Epoch 102/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.1109 - accuracy: 0.9688 - val_loss: 3.1724 - val_accuracy: 0.3313
# Epoch 103/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0718 - accuracy: 0.9792 - val_loss: 3.0618 - val_accuracy: 0.4062
# Epoch 104/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0538 - accuracy: 0.9844 - val_loss: 3.6921 - val_accuracy: 0.3625
# Epoch 105/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0470 - accuracy: 0.9896 - val_loss: 2.8906 - val_accuracy: 0.4250
# Epoch 106/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0279 - accuracy: 0.9937 - val_loss: 3.6588 - val_accuracy: 0.3625
# Epoch 107/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0168 - accuracy: 0.9969 - val_loss: 3.0657 - val_accuracy: 0.3938
# Epoch 108/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 3.2886 - val_accuracy: 0.3438
# Epoch 109/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0406 - accuracy: 0.9875 - val_loss: 4.0661 - val_accuracy: 0.2937
# Epoch 110/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0712 - accuracy: 0.9781 - val_loss: 3.8125 - val_accuracy: 0.3688
# Epoch 111/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0860 - accuracy: 0.9792 - val_loss: 4.7626 - val_accuracy: 0.2875
# Epoch 112/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.1516 - accuracy: 0.9583 - val_loss: 3.9530 - val_accuracy: 0.3063
# Epoch 113/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.1589 - accuracy: 0.9438 - val_loss: 3.8537 - val_accuracy: 0.3875
# Epoch 114/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0664 - accuracy: 0.9750 - val_loss: 4.4329 - val_accuracy: 0.3250
# Epoch 115/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.0970 - accuracy: 0.9708 - val_loss: 4.3592 - val_accuracy: 0.3500
# Epoch 116/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.1429 - accuracy: 0.9500 - val_loss: 4.8546 - val_accuracy: 0.2188
# Epoch 117/150
# 30/30 [==============================] - 428s 14s/step - loss: 0.1037 - accuracy: 0.9635 - val_loss: 3.3984 - val_accuracy: 0.3375
# Epoch 118/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0653 - accuracy: 0.9802 - val_loss: 4.4807 - val_accuracy: 0.3625
# Epoch 119/150
# 30/30 [==============================] - 416s 14s/step - loss: 0.0443 - accuracy: 0.9885 - val_loss: 4.5421 - val_accuracy: 0.2812
# Epoch 120/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0458 - accuracy: 0.9896 - val_loss: 4.1751 - val_accuracy: 0.3063
# Epoch 121/150
# 30/30 [==============================] - 416s 14s/step - loss: 0.0284 - accuracy: 0.9927 - val_loss: 3.7454 - val_accuracy: 0.3187
# Epoch 122/150
# 30/30 [==============================] - 416s 14s/step - loss: 0.0510 - accuracy: 0.9854 - val_loss: 4.1405 - val_accuracy: 0.3125
# Epoch 123/150
# 30/30 [==============================] - 416s 14s/step - loss: 0.0512 - accuracy: 0.9792 - val_loss: 4.0730 - val_accuracy: 0.2812
# Epoch 124/150
# 30/30 [==============================] - 415s 14s/step - loss: 0.0469 - accuracy: 0.9854 - val_loss: 3.3739 - val_accuracy: 0.3750
# Epoch 125/150
# 30/30 [==============================] - 415s 14s/step - loss: 0.0308 - accuracy: 0.9917 - val_loss: 3.7152 - val_accuracy: 0.3562
# Epoch 126/150
# 30/30 [==============================] - 416s 14s/step - loss: 0.0108 - accuracy: 0.9990 - val_loss: 3.0462 - val_accuracy: 0.4500
# Epoch 127/150
# 30/30 [==============================] - 415s 14s/step - loss: 0.0229 - accuracy: 0.9937 - val_loss: 3.5424 - val_accuracy: 0.4375
# Epoch 128/150
# 30/30 [==============================] - 415s 14s/step - loss: 0.0155 - accuracy: 0.9958 - val_loss: 3.6358 - val_accuracy: 0.4000
# Epoch 129/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0131 - accuracy: 0.9990 - val_loss: 3.6186 - val_accuracy: 0.3812
# Epoch 130/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 3.6203 - val_accuracy: 0.3750
# Epoch 131/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0131 - accuracy: 0.9969 - val_loss: 3.5045 - val_accuracy: 0.4187
# Epoch 132/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0270 - accuracy: 0.9896 - val_loss: 3.5445 - val_accuracy: 0.4250
# Epoch 133/150
# 30/30 [==============================] - 417s 14s/step - loss: 0.0478 - accuracy: 0.9854 - val_loss: 3.9937 - val_accuracy: 0.3625
# Epoch 134/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0774 - accuracy: 0.9750 - val_loss: 4.0416 - val_accuracy: 0.3000
# Epoch 135/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0742 - accuracy: 0.9802 - val_loss: 3.8803 - val_accuracy: 0.3375
# Epoch 136/150
# 30/30 [==============================] - 418s 14s/step - loss: 0.0779 - accuracy: 0.9729 - val_loss: 4.4313 - val_accuracy: 0.3063
# Epoch 137/150
# 30/30 [==============================] - 424s 14s/step - loss: 0.1482 - accuracy: 0.9521 - val_loss: 4.4207 - val_accuracy: 0.3375
# Epoch 138/150
# 30/30 [==============================] - 416s 14s/step - loss: 0.1508 - accuracy: 0.9510 - val_loss: 3.8850 - val_accuracy: 0.3438
# Epoch 139/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.1731 - accuracy: 0.9438 - val_loss: 4.5888 - val_accuracy: 0.2937
# Epoch 140/150
# 30/30 [==============================] - 424s 14s/step - loss: 0.1214 - accuracy: 0.9594 - val_loss: 3.5293 - val_accuracy: 0.3750
# Epoch 141/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0625 - accuracy: 0.9802 - val_loss: 3.5929 - val_accuracy: 0.4563
# Epoch 142/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0793 - accuracy: 0.9729 - val_loss: 3.3007 - val_accuracy: 0.3938
# Epoch 143/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.1771 - accuracy: 0.9427 - val_loss: 3.6770 - val_accuracy: 0.3125
# Epoch 144/150
# 30/30 [==============================] - 419s 14s/step - loss: 0.1662 - accuracy: 0.9490 - val_loss: 4.6444 - val_accuracy: 0.2750
# Epoch 145/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0758 - accuracy: 0.9760 - val_loss: 4.5451 - val_accuracy: 0.3063
# Epoch 146/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0709 - accuracy: 0.9792 - val_loss: 3.5090 - val_accuracy: 0.3875
# Epoch 147/150
# 30/30 [==============================] - 420s 14s/step - loss: 0.0331 - accuracy: 0.9885 - val_loss: 3.6554 - val_accuracy: 0.2875
# Epoch 148/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.0202 - accuracy: 0.9958 - val_loss: 3.4108 - val_accuracy: 0.3688
# Epoch 149/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 3.9735 - val_accuracy: 0.3750
# Epoch 150/150
# 30/30 [==============================] - 421s 14s/step - loss: 0.0469 - accuracy: 0.9844 - val_loss: 3.9263 - val_accuracy: 0.3375

# %% [markdown]
# ## Salvataggio parametri su file

# %%
filename = "3d_cnn_150.txt"  # Nome del file di destinazione

with open(filename, "w") as file:
    file.write("Image res: " + str(WIDTH) + "x" + str(HEIGHT) + "\n")
    file.write("Numero frames: " + str(n_frames) + "\n")
    file.write("Frame step: " + "3" + "\n")
    file.write("Batch size: " + str(batch_size) + "\n")
    file.write("Shuffle: " + "True" + "\n")
    file.write("Learning rate: Adam " + "(0.001)" + "\n")
    file.write("Spazial convolution: " + "7x7" + "\n")
    file.write("Time convolution: 3")

# %% [markdown]
# ## Visualizza i risultati
#
# Creare grafici della perdita e dell'accuratezza sui set di formazione e convalida:

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

plot_history(history)

# %% [markdown]
# # Valutare del modello
# Utilizzare Keras `model.evaluate` per ottenere la perdita e l'accuratezza sul set di dati di test.

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 5/5 [==============================] - 34s 7s/step - loss: 5.3340 - accuracy: 0.3625
# {'loss': 5.333975791931152, 'accuracy': 0.36250001192092896}

# %% [markdown]
# Per visualizzare ulteriormente le prestazioni del modello, utilizzare una matrice di confusione. La matrice di confusione consente di valutare le prestazioni del modello di classificazione oltre l'accuratezza. Per costruire la matrice di confusione per questo problema di classificazione multiclasse, ottenere i valori effettivi nel set di test e i valori previsti.

# %%
def get_actual_predicted_labels(dataset): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g')
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of babele for ' + ds_type)
  ax.set_xlabel('Predicted Action')
  ax.set_ylabel('Actual Action')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
fg = FrameGenerator(train_dir, n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# Rename the labels based on the provided mapping
label_mapping = {
    1: 'Italian',
    2: 'English',
    3: 'German',
    4: 'Spanish',
    5: 'Dutch',
    6: 'Russian',
    7: 'Japanese',
    8: 'French'
}

labels = [int(label) for label in labels]

renamed_labels = [label_mapping[label_id] for label_id in labels]

# Print the renamed labels
print(renamed_labels)
# Out:
# ['Italian', 'English', 'German', 'Spanish', 'Dutch', 'Russian', 'Japanese', 'French']

# %%
actual, predicted = get_actual_predicted_labels(train_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'training')
# Out:
# 30/30 [==============================] - 208s 7s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'test')
# Out:
# 5/5 [==============================] - 34s 7s/step

# %% [markdown]
# I valori di precision e recall per ogni classe possono anche essere calcolati utilizzando una matrice di confusione.

# %%
def calculate_classification_metrics(y_actual, y_pred, labels):
  """
    Calculate the precision and recall of a classification model using the ground truth and
    predicted values. 

    Args:
      y_actual: Ground truth labels.
      y_pred: Predicted labels.
      labels: List of classification labels.

    Return:
      Precision and recall measures.
  """
  cm = tf.math.confusion_matrix(y_actual, y_pred)
  tp = np.diag(cm) # Diagonal represents true positives
  precision = dict()
  recall = dict()
  for i in range(len(labels)):
    col = cm[:, i]
    fp = np.sum(col) - tp[i] # Sum of column minus true positive is false negative

    row = cm[i, :]
    fn = np.sum(row) - tp[i] # Sum of row minus true positive, is false negative

    precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision 

    recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

  return precision, recall

# %%
precision, recall = calculate_classification_metrics(actual, predicted, renamed_labels) # Test dataset

# %%
precision
# Out:
# {'Italian': 0.38461538461538464,
#  'English': 0.0,
#  'German': 0.38095238095238093,
#  'Spanish': 0.1388888888888889,
#  'Dutch': 0.7307692307692307,
#  'Russian': 0.75,
#  'Japanese': 1.0,
#  'French': 0.17857142857142858}

# %%
recall
# Out:
# {'Italian': 0.25,
#  'English': 0.0,
#  'German': 0.8,
#  'Spanish': 0.25,
#  'Dutch': 0.95,
#  'Russian': 0.3,
#  'Japanese': 0.2,
#  'French': 0.25}

# %%
# Save the weights
model.save_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_3D/3dCNN_150_epoche/Pesi_Modello/pesi_3dcnn_150_epoche')

# Restore the weights
model.load_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_3D/3dCNN_150_epoche/Pesi_Modello/pesi_3dcnn_150_epoche')

model.compile(loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              optimizer = keras.optimizers.Adam(learning_rate = 0.001), 
              metrics = ['accuracy'])

# Evaluate the model
loss, acc = model.evaluate(test_ds, verbose=2)
print("Modello caricato: accuracy: {:5.2f}%".format(100 * acc))
# Out:
# c:\Users\Vincenzo\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 5/5 - 34s - loss: 5.3479 - accuracy: 0.3313 - 34s/epoch - 7s/step
# Modello caricato: accuracy: 33.13%
