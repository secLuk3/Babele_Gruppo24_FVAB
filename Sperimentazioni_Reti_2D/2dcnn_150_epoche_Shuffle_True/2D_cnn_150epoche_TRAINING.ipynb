# %% [markdown]
# # Setup

# %% [markdown]
# Inizia installando e importando alcune librerie necessarie, tra cui: tqdm per utilizzare una barra di avanzamento, OpenCV per elaborare file video e `tensorflow_docs` per incorporare i dati in un notebook Jupyter.

# %%
# The way this tutorial uses the `TimeDistributed` layer requires TF>=2.10
# %pip install -U "tensorflow==2.10.0"

# %%
# %pip install remotezip tqdm opencv-python
# %pip install -q git+https://github.com/tensorflow/docs
# Out:
# Requirement already satisfied: remotezip in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (0.12.1)
# Requirement already satisfied: tqdm in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.65.0)
# Requirement already satisfied: opencv-python in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.7.0.72)
# Requirement already satisfied: requests in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from remotezip) (2.31.0)
# Requirement already satisfied: tabulate in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from remotezip) (0.9.0)
# Requirement already satisfied: colorama in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tqdm
import random
import pathlib
import itertools
import collections
import seaborn as sns

import os
import cv2
import numpy as np
import remotezip as rz

import tensorflow as tf

import shutil #roba fresca aggiunta da poco
import matplotlib.pyplot as plt

# Some modules to display an animation using imageio.
import imageio
from IPython import display
from urllib import request
from tensorflow_docs.vis import embed

# %% [markdown]
# # Fase di Pre-Processing

# %% [markdown]
# Definire la funzione `get_class` che recupera il nome della classe da un nome di file. Quindi, creare una funzione chiamata `get_files_per_class` che converte l'elenco di tutti i file (file sopra) in un dizionario che elenca i file per ogni classe:

# %%
def get_class(fname):
  """ Retrieve the name of the class given a filename.

    Args:
      fname: Name of the file in the UCF101 dataset.

    Returns:
      Class that the file belongs to.
  """
  return fname.split('_')[-7]

# %%
def get_files_per_class(files):
  """ Retrieve the files that belong to each class.

    Args:
      files: List of files in the dataset.

    Returns:
      Dictionary of class names (key) and files (values). 
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %% [markdown]
# Esegui il seguente codice per stampare il numero totale di video che hai tra tutte le sottocartelle del dataset.

# %%
download_dir = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val")

video_count_train = len(list(download_dir.glob('Train/*/*.avi')))
video_count_val = len(list(download_dir.glob('Validation/*/*.avi')))
video_count_test = len(list(download_dir.glob('Test/*/*.avi')))
video_total = video_count_train + video_count_val + video_count_test

print(f"print_train: {video_count_train}")
print(f"print_val: {video_count_val}")
print(f"print_test: {video_count_test}")
print(f"Total videos: {video_total}")
# Out:
# print_train: 960
# print_val: 160
# print_test: 160
# Total videos: 1280

# %% [markdown]
# # Crea fotogrammi da ogni file video

# %% [markdown]
# La funzione `frames_from_video_file` divide i video in frame, legge un intervallo scelto a caso di `n_frames` da un file video e li restituisce come array NumPy. Per ridurre la memoria e il sovraccarico di calcolo, scegliere un **piccolo** numero di fotogrammi. Inoltre, scegli lo stesso numero di fotogrammi da ogni video, il che rende più facile lavorare su lotti di dati.

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.
    
    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

# %%
def frames_from_video_file(video_path, n_frames, output_size = (80, 120), frame_step = 2):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))  

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

# %% [markdown]
# # Visualizza dati video

# %% [markdown]
# Snippet di codice per fare un gif dato un video preso a caso nella cartella di Train

# %%
def to_gif(images):
  converted_images = np.clip(images * 255, 0, 255).astype(np.uint8)
  imageio.mimsave('./animation.gif', converted_images, duration = 125)
  return embed.embed_file('./animation.gif')

# docs-infra: no-execute
ucf_sample_video = frames_from_video_file(next(download_dir.glob('Train/*/*.avi')), 60)
to_gif(ucf_sample_video)
# Out:
# <img src="data:image/gif;base64,..."/>

# %% [markdown]
# Successivamente, definire la classe `FrameGenerator` per creare un oggetto iterabile in grado di immettere dati nella pipeline di dati TensorFlow. La funzione generatore (`__call__`) produce l'array di frame prodotto da `frames_from_video_file` e un vettore codificato one-hot dell'etichetta associata all'insieme di frame.

# %%
class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.avi'))
    classes = [p.parent.name for p in video_paths] 
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames) 
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %% [markdown]
# ## Configurazione sul dataset per le perfomance
#
# Utilizzare il prefetching con buffer in modo da poter produrre dati dal disco senza che l'I/O diventi un blocco. Due funzioni importanti da utilizzare durante il caricamento dei dati sono:
#
# * `Dataset.cache`: mantiene i set di frame in memoria dopo che sono stati caricati dal disco durante la prima epoca. Questa funzione assicura che il set di dati non diventi un collo di bottiglia durante l'addestramento del modello. Se il tuo set di dati è troppo grande per entrare in memoria, puoi anche usare questo metodo per creare una cache su disco performante.
#
# * `Dataset.prefetch`: sovrappone la preelaborazione dei dati e l'esecuzione del modello durante l'addestramento.

# %% [markdown]
# Per preparare i dati da immessi nel modello, utilizzare il batching come mostrato di seguito. Si noti che quando si lavora con dati video, come i file AVI, i dati dovrebbero essere modellati come un oggetto a cinque dimensioni. Queste dimensioni sono le seguenti:`[batch_size, number_of_frames, height, width, channels]`. In confronto, un'immagine avrebbe quattro dimensioni:`[batch_size, height, width, channels]`. L'immagine qui sotto è un'illustrazione di come viene rappresentata la forma dei dati video.
#
# ![Video data shape](https://www.tensorflow.org/images/tutorials/video/video_data_shape.png)

# %%
n_frames = 60
batch_size = 32

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_path = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Train")
test_path = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Test")
val_path = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Validation")


train_ds = tf.data.Dataset.from_generator(FrameGenerator(train_path, n_frames, training=True),
                                          output_signature = output_signature)
# Batch the data
train_ds = train_ds.batch(batch_size)


val_ds = tf.data.Dataset.from_generator(FrameGenerator(val_path, n_frames),
                                        output_signature = output_signature)
val_ds = val_ds.batch(batch_size)


test_ds = tf.data.Dataset.from_generator(FrameGenerator(test_path, n_frames),
                                         output_signature = output_signature)
test_ds = test_ds.batch(batch_size)

# %% [markdown]
# ## Definire la rete
#
# Ora che hai creato un TensorFlow `Dataset` di fotogrammi video con le loro etichette, puoi usarlo con un modello di apprendimento profondo. Il seguente modello di classificazione che utilizza un modello  [EfficientNet](https://arxiv.org/abs/1905.11946){:.external}  pre-addestrato:

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

net = tf.keras.applications.EfficientNetB0(include_top = False)
net.trainable = False

# Definizione del modello
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(scale=255),
    tf.keras.layers.TimeDistributed(net),
    tf.keras.layers.Dense(8),
    tf.keras.layers.GlobalAveragePooling3D(),
])

# %%
model.compile(optimizer = optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
history = model.fit(train_ds, 
          epochs = 150,
          shuffle = True,
          validation_data = val_ds)
          #callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))
# Out:
# Epoch 1/150
# 30/30 [==============================] - 513s 17s/step - loss: 2.1783 - accuracy: 0.1146 - val_loss: 2.1022 - val_accuracy: 0.1625
# Epoch 2/150
# 30/30 [==============================] - 488s 16s/step - loss: 2.0944 - accuracy: 0.1094 - val_loss: 2.0502 - val_accuracy: 0.1688
# Epoch 3/150
# 30/30 [==============================] - 480s 16s/step - loss: 2.0509 - accuracy: 0.1948 - val_loss: 2.0250 - val_accuracy: 0.1750
# Epoch 4/150
# 30/30 [==============================] - 476s 16s/step - loss: 2.0188 - accuracy: 0.2135 - val_loss: 1.9959 - val_accuracy: 0.1813
# Epoch 5/150
# 30/30 [==============================] - 470s 16s/step - loss: 1.9888 - accuracy: 0.2510 - val_loss: 1.9756 - val_accuracy: 0.2250
# Epoch 6/150
# 30/30 [==============================] - 481s 16s/step - loss: 1.9589 - accuracy: 0.2812 - val_loss: 1.9602 - val_accuracy: 0.2062
# Epoch 7/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.9344 - accuracy: 0.2896 - val_loss: 1.9402 - val_accuracy: 0.2250
# Epoch 8/150
# 30/30 [==============================] - 469s 16s/step - loss: 1.9116 - accuracy: 0.3323 - val_loss: 1.9245 - val_accuracy: 0.2562
# Epoch 9/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.8943 - accuracy: 0.3271 - val_loss: 1.9158 - val_accuracy: 0.2062
# Epoch 10/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.8731 - accuracy: 0.3531 - val_loss: 1.8989 - val_accuracy: 0.2313
# Epoch 11/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.8555 - accuracy: 0.3656 - val_loss: 1.8905 - val_accuracy: 0.2500
# Epoch 12/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.8345 - accuracy: 0.3708 - val_loss: 1.8789 - val_accuracy: 0.2438
# Epoch 13/150
# 30/30 [==============================] - 470s 16s/step - loss: 1.8213 - accuracy: 0.3948 - val_loss: 1.8760 - val_accuracy: 0.2875
# Epoch 14/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.8043 - accuracy: 0.3792 - val_loss: 1.8650 - val_accuracy: 0.2875
# Epoch 15/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.7864 - accuracy: 0.4052 - val_loss: 1.8438 - val_accuracy: 0.3125
# Epoch 16/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.7777 - accuracy: 0.4021 - val_loss: 1.8483 - val_accuracy: 0.3125
# Epoch 17/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.7620 - accuracy: 0.4208 - val_loss: 1.8346 - val_accuracy: 0.2875
# Epoch 18/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.7477 - accuracy: 0.4281 - val_loss: 1.8310 - val_accuracy: 0.2875
# Epoch 19/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.7325 - accuracy: 0.4354 - val_loss: 1.8239 - val_accuracy: 0.3250
# Epoch 20/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.7192 - accuracy: 0.4521 - val_loss: 1.8199 - val_accuracy: 0.3313
# Epoch 21/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.7032 - accuracy: 0.4635 - val_loss: 1.8204 - val_accuracy: 0.3063
# Epoch 22/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.6969 - accuracy: 0.4635 - val_loss: 1.8062 - val_accuracy: 0.3250
# Epoch 23/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.6884 - accuracy: 0.4677 - val_loss: 1.8109 - val_accuracy: 0.3187
# Epoch 24/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.6782 - accuracy: 0.4531 - val_loss: 1.8030 - val_accuracy: 0.3438
# Epoch 25/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.6704 - accuracy: 0.4781 - val_loss: 1.7965 - val_accuracy: 0.3063
# Epoch 26/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.6561 - accuracy: 0.4729 - val_loss: 1.7903 - val_accuracy: 0.3500
# Epoch 27/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.6379 - accuracy: 0.4938 - val_loss: 1.7994 - val_accuracy: 0.3500
# Epoch 28/150
# 30/30 [==============================] - 478s 16s/step - loss: 1.6303 - accuracy: 0.4833 - val_loss: 1.8015 - val_accuracy: 0.3187
# Epoch 29/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.6264 - accuracy: 0.4812 - val_loss: 1.7956 - val_accuracy: 0.3438
# Epoch 30/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.6099 - accuracy: 0.5052 - val_loss: 1.7914 - val_accuracy: 0.3500
# Epoch 31/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.6050 - accuracy: 0.4906 - val_loss: 1.7817 - val_accuracy: 0.3500
# Epoch 32/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.5985 - accuracy: 0.5135 - val_loss: 1.7746 - val_accuracy: 0.3938
# Epoch 33/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.5874 - accuracy: 0.5135 - val_loss: 1.7687 - val_accuracy: 0.3562
# Epoch 34/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.5783 - accuracy: 0.5125 - val_loss: 1.7777 - val_accuracy: 0.3438
# Epoch 35/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.5649 - accuracy: 0.5260 - val_loss: 1.7624 - val_accuracy: 0.3875
# Epoch 36/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.5635 - accuracy: 0.5198 - val_loss: 1.7584 - val_accuracy: 0.3688
# Epoch 37/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.5562 - accuracy: 0.5365 - val_loss: 1.7620 - val_accuracy: 0.3500
# Epoch 38/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.5504 - accuracy: 0.5375 - val_loss: 1.7653 - val_accuracy: 0.3500
# Epoch 39/150
# 30/30 [==============================] - 479s 16s/step - loss: 1.5396 - accuracy: 0.5292 - val_loss: 1.7587 - val_accuracy: 0.3688
# Epoch 40/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.5329 - accuracy: 0.5344 - val_loss: 1.7602 - val_accuracy: 0.3750
# Epoch 41/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.5266 - accuracy: 0.5594 - val_loss: 1.7539 - val_accuracy: 0.3750
# Epoch 42/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.5118 - accuracy: 0.5531 - val_loss: 1.7631 - val_accuracy: 0.3500
# Epoch 43/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.5093 - accuracy: 0.5500 - val_loss: 1.7500 - val_accuracy: 0.3688
# Epoch 44/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.5036 - accuracy: 0.5625 - val_loss: 1.7570 - val_accuracy: 0.3812
# Epoch 45/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.4856 - accuracy: 0.5635 - val_loss: 1.7423 - val_accuracy: 0.3812
# Epoch 46/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.4870 - accuracy: 0.5542 - val_loss: 1.7436 - val_accuracy: 0.3750
# Epoch 47/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.4802 - accuracy: 0.5646 - val_loss: 1.7391 - val_accuracy: 0.3812
# Epoch 48/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.4681 - accuracy: 0.5698 - val_loss: 1.7536 - val_accuracy: 0.3812
# Epoch 49/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.4678 - accuracy: 0.5740 - val_loss: 1.7351 - val_accuracy: 0.3812
# Epoch 50/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.4578 - accuracy: 0.5750 - val_loss: 1.7548 - val_accuracy: 0.3562
# Epoch 51/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.4477 - accuracy: 0.5906 - val_loss: 1.7541 - val_accuracy: 0.3688
# Epoch 52/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.4539 - accuracy: 0.5750 - val_loss: 1.7484 - val_accuracy: 0.3875
# Epoch 53/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.4345 - accuracy: 0.5875 - val_loss: 1.7279 - val_accuracy: 0.3812
# Epoch 54/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.4368 - accuracy: 0.5729 - val_loss: 1.7375 - val_accuracy: 0.3812
# Epoch 55/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.4272 - accuracy: 0.5917 - val_loss: 1.7297 - val_accuracy: 0.3938
# Epoch 56/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.4291 - accuracy: 0.5833 - val_loss: 1.7521 - val_accuracy: 0.3625
# Epoch 57/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.4186 - accuracy: 0.5833 - val_loss: 1.7388 - val_accuracy: 0.3875
# Epoch 58/150
# 30/30 [==============================] - 477s 16s/step - loss: 1.4117 - accuracy: 0.5885 - val_loss: 1.7365 - val_accuracy: 0.3750
# Epoch 59/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.3994 - accuracy: 0.5979 - val_loss: 1.7271 - val_accuracy: 0.3938
# Epoch 60/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.4011 - accuracy: 0.5917 - val_loss: 1.7310 - val_accuracy: 0.4125
# Epoch 61/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.3954 - accuracy: 0.5990 - val_loss: 1.7187 - val_accuracy: 0.4000
# Epoch 62/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.3952 - accuracy: 0.5948 - val_loss: 1.7255 - val_accuracy: 0.4000
# Epoch 63/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.3797 - accuracy: 0.6125 - val_loss: 1.7262 - val_accuracy: 0.4125
# Epoch 64/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.3742 - accuracy: 0.6094 - val_loss: 1.7348 - val_accuracy: 0.3812
# Epoch 65/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.3733 - accuracy: 0.5927 - val_loss: 1.7089 - val_accuracy: 0.4125
# Epoch 66/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.3652 - accuracy: 0.6094 - val_loss: 1.7131 - val_accuracy: 0.4062
# Epoch 67/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.3609 - accuracy: 0.6073 - val_loss: 1.7292 - val_accuracy: 0.3812
# Epoch 68/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.3548 - accuracy: 0.5948 - val_loss: 1.7251 - val_accuracy: 0.3688
# Epoch 69/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.3434 - accuracy: 0.6156 - val_loss: 1.7228 - val_accuracy: 0.4000
# Epoch 70/150
# 30/30 [==============================] - 480s 16s/step - loss: 1.3411 - accuracy: 0.6198 - val_loss: 1.7124 - val_accuracy: 0.4000
# Epoch 71/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.3487 - accuracy: 0.6052 - val_loss: 1.7265 - val_accuracy: 0.3938
# Epoch 72/150
# 30/30 [==============================] - 470s 16s/step - loss: 1.3385 - accuracy: 0.6135 - val_loss: 1.7265 - val_accuracy: 0.3812
# Epoch 73/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.3254 - accuracy: 0.6219 - val_loss: 1.7069 - val_accuracy: 0.3562
# Epoch 74/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.3292 - accuracy: 0.6146 - val_loss: 1.7272 - val_accuracy: 0.3812
# Epoch 75/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.3214 - accuracy: 0.6115 - val_loss: 1.7314 - val_accuracy: 0.4187
# Epoch 76/150
# 30/30 [==============================] - 470s 16s/step - loss: 1.3156 - accuracy: 0.6417 - val_loss: 1.7224 - val_accuracy: 0.4062
# Epoch 77/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.3096 - accuracy: 0.6260 - val_loss: 1.7201 - val_accuracy: 0.3625
# Epoch 78/150
# 30/30 [==============================] - 478s 16s/step - loss: 1.3042 - accuracy: 0.6333 - val_loss: 1.7059 - val_accuracy: 0.4000
# Epoch 79/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.3011 - accuracy: 0.6438 - val_loss: 1.7189 - val_accuracy: 0.3938
# Epoch 80/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.2968 - accuracy: 0.6323 - val_loss: 1.7057 - val_accuracy: 0.3875
# Epoch 81/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.2836 - accuracy: 0.6438 - val_loss: 1.7016 - val_accuracy: 0.4187
# Epoch 82/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.2921 - accuracy: 0.6469 - val_loss: 1.7207 - val_accuracy: 0.3750
# Epoch 83/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.2928 - accuracy: 0.6271 - val_loss: 1.7094 - val_accuracy: 0.4000
# Epoch 84/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.2835 - accuracy: 0.6344 - val_loss: 1.7032 - val_accuracy: 0.4125
# Epoch 85/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.2810 - accuracy: 0.6406 - val_loss: 1.7156 - val_accuracy: 0.4187
# Epoch 86/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.2674 - accuracy: 0.6458 - val_loss: 1.7095 - val_accuracy: 0.3875
# Epoch 87/150
# 30/30 [==============================] - 482s 16s/step - loss: 1.2648 - accuracy: 0.6531 - val_loss: 1.7347 - val_accuracy: 0.4000
# Epoch 88/150
# 30/30 [==============================] - 491s 16s/step - loss: 1.2576 - accuracy: 0.6469 - val_loss: 1.7312 - val_accuracy: 0.3812
# Epoch 89/150
# 30/30 [==============================] - 496s 17s/step - loss: 1.2565 - accuracy: 0.6448 - val_loss: 1.7335 - val_accuracy: 0.3812
# Epoch 90/150
# 30/30 [==============================] - 491s 16s/step - loss: 1.2497 - accuracy: 0.6531 - val_loss: 1.7115 - val_accuracy: 0.4000
# Epoch 91/150
# 30/30 [==============================] - 507s 17s/step - loss: 1.2460 - accuracy: 0.6562 - val_loss: 1.7209 - val_accuracy: 0.4125
# Epoch 92/150
# 30/30 [==============================] - 519s 17s/step - loss: 1.2441 - accuracy: 0.6521 - val_loss: 1.7238 - val_accuracy: 0.4000
# Epoch 93/150
# 30/30 [==============================] - 514s 17s/step - loss: 1.2366 - accuracy: 0.6615 - val_loss: 1.7158 - val_accuracy: 0.4313
# Epoch 94/150
# 30/30 [==============================] - 495s 17s/step - loss: 1.2360 - accuracy: 0.6542 - val_loss: 1.7123 - val_accuracy: 0.3875
# Epoch 95/150
# 30/30 [==============================] - 487s 16s/step - loss: 1.2319 - accuracy: 0.6646 - val_loss: 1.7138 - val_accuracy: 0.4125
# Epoch 96/150
# 30/30 [==============================] - 471s 16s/step - loss: 1.2305 - accuracy: 0.6521 - val_loss: 1.7133 - val_accuracy: 0.4187
# Epoch 97/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.2223 - accuracy: 0.6698 - val_loss: 1.7153 - val_accuracy: 0.4000
# Epoch 98/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.2237 - accuracy: 0.6656 - val_loss: 1.7143 - val_accuracy: 0.3938
# Epoch 99/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.2176 - accuracy: 0.6615 - val_loss: 1.7168 - val_accuracy: 0.3875
# Epoch 100/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.2137 - accuracy: 0.6615 - val_loss: 1.7420 - val_accuracy: 0.4062
# Epoch 101/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.2113 - accuracy: 0.6698 - val_loss: 1.7166 - val_accuracy: 0.3875
# Epoch 102/150
# 30/30 [==============================] - 490s 16s/step - loss: 1.2007 - accuracy: 0.6635 - val_loss: 1.7159 - val_accuracy: 0.4062
# Epoch 103/150
# 30/30 [==============================] - 494s 17s/step - loss: 1.2061 - accuracy: 0.6604 - val_loss: 1.7196 - val_accuracy: 0.4125
# Epoch 104/150
# 30/30 [==============================] - 489s 16s/step - loss: 1.1947 - accuracy: 0.6781 - val_loss: 1.7144 - val_accuracy: 0.4062
# Epoch 105/150
# 30/30 [==============================] - 467s 16s/step - loss: 1.2015 - accuracy: 0.6594 - val_loss: 1.7409 - val_accuracy: 0.3875
# Epoch 106/150
# 30/30 [==============================] - 493s 17s/step - loss: 1.1822 - accuracy: 0.6792 - val_loss: 1.7247 - val_accuracy: 0.4062
# Epoch 107/150
# 30/30 [==============================] - 494s 17s/step - loss: 1.1848 - accuracy: 0.6792 - val_loss: 1.7114 - val_accuracy: 0.4000
# Epoch 108/150
# 30/30 [==============================] - 463s 16s/step - loss: 1.1848 - accuracy: 0.6708 - val_loss: 1.7376 - val_accuracy: 0.4250
# Epoch 109/150
# 30/30 [==============================] - 477s 16s/step - loss: 1.1777 - accuracy: 0.6865 - val_loss: 1.7187 - val_accuracy: 0.4250
# Epoch 110/150
# 30/30 [==============================] - 474s 16s/step - loss: 1.1744 - accuracy: 0.6875 - val_loss: 1.7165 - val_accuracy: 0.4125
# Epoch 111/150
# 30/30 [==============================] - 480s 16s/step - loss: 1.1715 - accuracy: 0.6771 - val_loss: 1.7315 - val_accuracy: 0.4125
# Epoch 112/150
# 30/30 [==============================] - 497s 17s/step - loss: 1.1764 - accuracy: 0.6677 - val_loss: 1.7137 - val_accuracy: 0.4250
# Epoch 113/150
# 30/30 [==============================] - 470s 16s/step - loss: 1.1783 - accuracy: 0.6792 - val_loss: 1.6913 - val_accuracy: 0.4437
# Epoch 114/150
# 30/30 [==============================] - 487s 16s/step - loss: 1.1601 - accuracy: 0.6802 - val_loss: 1.7182 - val_accuracy: 0.4187
# Epoch 115/150
# 30/30 [==============================] - 496s 17s/step - loss: 1.1610 - accuracy: 0.6792 - val_loss: 1.7252 - val_accuracy: 0.4125
# Epoch 116/150
# 30/30 [==============================] - 476s 16s/step - loss: 1.1534 - accuracy: 0.6812 - val_loss: 1.7129 - val_accuracy: 0.4125
# Epoch 117/150
# 30/30 [==============================] - 488s 16s/step - loss: 1.1520 - accuracy: 0.6844 - val_loss: 1.7168 - val_accuracy: 0.4187
# Epoch 118/150
# 30/30 [==============================] - 468s 16s/step - loss: 1.1598 - accuracy: 0.6698 - val_loss: 1.7235 - val_accuracy: 0.4125
# Epoch 119/150
# 30/30 [==============================] - 505s 17s/step - loss: 1.1393 - accuracy: 0.6990 - val_loss: 1.7444 - val_accuracy: 0.4000
# Epoch 120/150
# 30/30 [==============================] - 524s 18s/step - loss: 1.1426 - accuracy: 0.6917 - val_loss: 1.7087 - val_accuracy: 0.4062
# Epoch 121/150
# 30/30 [==============================] - 514s 17s/step - loss: 1.1378 - accuracy: 0.6938 - val_loss: 1.7222 - val_accuracy: 0.4062
# Epoch 122/150
# 30/30 [==============================] - 517s 17s/step - loss: 1.1342 - accuracy: 0.6938 - val_loss: 1.7142 - val_accuracy: 0.4187
# Epoch 123/150
# 30/30 [==============================] - 485s 16s/step - loss: 1.1316 - accuracy: 0.6906 - val_loss: 1.7280 - val_accuracy: 0.3812
# Epoch 124/150
# 30/30 [==============================] - 472s 16s/step - loss: 1.1325 - accuracy: 0.6990 - val_loss: 1.7353 - val_accuracy: 0.4187
# Epoch 125/150
# 30/30 [==============================] - 511s 17s/step - loss: 1.1213 - accuracy: 0.6969 - val_loss: 1.6981 - val_accuracy: 0.4062
# Epoch 126/150
# 30/30 [==============================] - 508s 17s/step - loss: 1.1251 - accuracy: 0.7000 - val_loss: 1.7010 - val_accuracy: 0.4000
# Epoch 127/150
# 30/30 [==============================] - 506s 17s/step - loss: 1.1161 - accuracy: 0.7031 - val_loss: 1.7259 - val_accuracy: 0.4000
# Epoch 128/150
# 30/30 [==============================] - 516s 17s/step - loss: 1.1151 - accuracy: 0.6958 - val_loss: 1.7063 - val_accuracy: 0.4250
# Epoch 129/150
# 30/30 [==============================] - 515s 17s/step - loss: 1.1199 - accuracy: 0.6948 - val_loss: 1.7317 - val_accuracy: 0.3938
# Epoch 130/150
# 30/30 [==============================] - 532s 18s/step - loss: 1.1164 - accuracy: 0.6896 - val_loss: 1.7141 - val_accuracy: 0.4250
# Epoch 131/150
# 30/30 [==============================] - 512s 17s/step - loss: 1.1118 - accuracy: 0.6958 - val_loss: 1.7434 - val_accuracy: 0.4062
# Epoch 132/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.1028 - accuracy: 0.6990 - val_loss: 1.7330 - val_accuracy: 0.3750
# Epoch 133/150
# 30/30 [==============================] - 529s 18s/step - loss: 1.1053 - accuracy: 0.6969 - val_loss: 1.7566 - val_accuracy: 0.4062
# Epoch 134/150
# 30/30 [==============================] - 528s 18s/step - loss: 1.1027 - accuracy: 0.6844 - val_loss: 1.7018 - val_accuracy: 0.4062
# Epoch 135/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.0994 - accuracy: 0.7063 - val_loss: 1.7142 - val_accuracy: 0.4000
# Epoch 136/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.0850 - accuracy: 0.7115 - val_loss: 1.7433 - val_accuracy: 0.4125
# Epoch 137/150
# 30/30 [==============================] - 521s 17s/step - loss: 1.0958 - accuracy: 0.7000 - val_loss: 1.7248 - val_accuracy: 0.4000
# Epoch 138/150
# 30/30 [==============================] - 507s 17s/step - loss: 1.0902 - accuracy: 0.7042 - val_loss: 1.7191 - val_accuracy: 0.3938
# Epoch 139/150
# 30/30 [==============================] - 502s 17s/step - loss: 1.0864 - accuracy: 0.7021 - val_loss: 1.7421 - val_accuracy: 0.4000
# Epoch 140/150
# 30/30 [==============================] - 502s 17s/step - loss: 1.0883 - accuracy: 0.7010 - val_loss: 1.7127 - val_accuracy: 0.4125
# Epoch 141/150
# 30/30 [==============================] - 501s 17s/step - loss: 1.0753 - accuracy: 0.7094 - val_loss: 1.7258 - val_accuracy: 0.4062
# Epoch 142/150
# 30/30 [==============================] - 502s 17s/step - loss: 1.0736 - accuracy: 0.7125 - val_loss: 1.7336 - val_accuracy: 0.4187
# Epoch 143/150
# 30/30 [==============================] - 501s 17s/step - loss: 1.0727 - accuracy: 0.7115 - val_loss: 1.7194 - val_accuracy: 0.4313
# Epoch 144/150
# 30/30 [==============================] - 501s 17s/step - loss: 1.0664 - accuracy: 0.7177 - val_loss: 1.7253 - val_accuracy: 0.4250
# Epoch 145/150
# 30/30 [==============================] - 501s 17s/step - loss: 1.0545 - accuracy: 0.7083 - val_loss: 1.7232 - val_accuracy: 0.4000
# Epoch 146/150
# 30/30 [==============================] - 502s 17s/step - loss: 1.0522 - accuracy: 0.7177 - val_loss: 1.7135 - val_accuracy: 0.4062
# Epoch 147/150
# 30/30 [==============================] - 501s 17s/step - loss: 1.0578 - accuracy: 0.7250 - val_loss: 1.7247 - val_accuracy: 0.4062
# Epoch 148/150
# 30/30 [==============================] - 501s 17s/step - loss: 1.0601 - accuracy: 0.7146 - val_loss: 1.7245 - val_accuracy: 0.4062
# Epoch 149/150
# 30/30 [==============================] - 501s 17s/step - loss: 1.0573 - accuracy: 0.7156 - val_loss: 1.7231 - val_accuracy: 0.4250
# Epoch 150/150
# 30/30 [==============================] - 507s 17s/step - loss: 1.0558 - accuracy: 0.7135 - val_loss: 1.7157 - val_accuracy: 0.4000

# %% [markdown]
# ## Salvataggio parametri su file

# %%
filename = "2d_cnn_150_Vincenzo.txt"  # Nome del file di destinazione

with open(filename, "w") as file:
    file.write("Batch size: " + str(batch_size) + "\n")
    file.write("Shuffle: " + "True" + "\n")
    file.write("Numero frames: " + str(n_frames) + "\n")
    file.write("Frame step: " + "2" + "\n")
    file.write("Image res: " +  "120x80"  + "\n")
    file.write("Learning rate: Adam " + "(0.0001)" + "\n")

# %%
# Visualize the model
tf.keras.utils.plot_model(model, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

plot_history(history)

# %% [markdown]
# # Valutare il modello

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 5/5 [==============================] - 72s 14s/step - loss: 1.7140 - accuracy: 0.4187
# {'loss': 1.7140363454818726, 'accuracy': 0.41874998807907104}

# %%
def get_actual_predicted_labels(dataset): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g')
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of babele for ' + ds_type)
  ax.set_xlabel('Predicted Language')
  ax.set_ylabel('Actual Language')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
fg = FrameGenerator(train_path, n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# Rename the labels based on the provided mapping
label_mapping = {
    1: 'Italian',
    2: 'English',
    3: 'German',
    4: 'Spanish',
    5: 'Dutch',
    6: 'Russian',
    7: 'Japanese',
    8: 'French'
}

labels = [int(label) for label in labels]

renamed_labels = [label_mapping[label_id] for label_id in labels]

# Print the renamed labels
print(renamed_labels)
# Out:
# ['Italian', 'English', 'German', 'Spanish', 'Dutch', 'Russian', 'Japanese', 'French']

# %%
actual, predicted = get_actual_predicted_labels(train_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'training')
# Out:
# 30/30 [==============================] - 435s 14s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'test')
# Out:
# 5/5 [==============================] - 75s 15s/step

# %%
def calculate_classification_metrics(y_actual, y_pred, labels):
  """
    Calculate the precision and recall of a classification model using the ground truth and
    predicted values. 

    Args:
      y_actual: Ground truth labels.
      y_pred: Predicted labels.
      labels: List of classification labels.

    Return:
      Precision and recall measures.
  """
  cm = tf.math.confusion_matrix(y_actual, y_pred)
  tp = np.diag(cm) # Diagonal represents true positives
  precision = dict()
  recall = dict()
  for i in range(len(labels)):
    col = cm[:, i]
    fp = np.sum(col) - tp[i] # Sum of column minus true positive is false negative

    row = cm[i, :]
    fn = np.sum(row) - tp[i] # Sum of row minus true positive, is false negative

    precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision 

    recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

  return precision, recall

# %%
precision, recall = calculate_classification_metrics(actual, predicted, renamed_labels) # Test dataset

# %%
precision
# Out:
# {'Italian': 0.45,
#  'English': 0.11764705882352941,
#  'German': 0.7894736842105263,
#  'Spanish': 0.3076923076923077,
#  'Dutch': 0.53125,
#  'Russian': 0.14285714285714285,
#  'Japanese': 0.23809523809523808,
#  'French': 0.3870967741935484}

# %%
recall
# Out:
# {'Italian': 0.45,
#  'English': 0.1,
#  'German': 0.75,
#  'Spanish': 0.2,
#  'Dutch': 0.85,
#  'Russian': 0.05,
#  'Japanese': 0.25,
#  'French': 0.6}

# %% [markdown]
# # Salvo il modello

# %%
# Save the weights
model.save_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_2D/2dcnn_150_epoche_Shuffle/Pesi_Modello/pesi_2dcnn_150_epoche')

# Restore the weights
model.load_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_2D/2dcnn_150_epoche_Shuffle/Pesi_Modello/pesi_2dcnn_150_epoche')

model.compile(optimizer = optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# Evaluate the model
loss, acc = model.evaluate(test_ds, verbose=2)
print("Modello caricato: accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 5/5 - 76s - loss: 1.7285 - accuracy: 0.3875 - 76s/epoch - 15s/step
# Modello caricato: accuracy: 38.75%
