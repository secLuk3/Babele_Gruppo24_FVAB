# %% [markdown]
# # Setup

# %% [markdown]
# Inizia installando e importando alcune librerie necessarie, tra cui: tqdm per utilizzare una barra di avanzamento, OpenCV per elaborare file video e `tensorflow_docs` per incorporare i dati in un notebook Jupyter.

# %%
# The way this tutorial uses the `TimeDistributed` layer requires TF>=2.10
# %pip install -U "tensorflow==2.10.0"
# Out:
# Requirement already satisfied: tensorflow==2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (16.0.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (23.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (49.2.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tensorflow==2.10.0) (4.6.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (1.54.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.19.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.3.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (6.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install remotezip tqdm opencv-python
# %pip install -q git+https://github.com/tensorflow/docs
# Out:
# Requirement already satisfied: remotezip in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (0.12.1)
# Requirement already satisfied: tqdm in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.65.0)
# Requirement already satisfied: opencv-python in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (4.7.0.72)
# Requirement already satisfied: requests in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from remotezip) (2.31.0)
# Requirement already satisfied: tabulate in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from remotezip) (0.9.0)
# Requirement already satisfied: colorama in c:\users\vincenzo\appdata\roaming\python\python39\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vincenzo\appdata\local\programs\python\python39\lib\site-packages (from requests->remotezip) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tqdm
import random
import pathlib
import itertools
import collections
import seaborn as sns

import os
import cv2
import numpy as np
import remotezip as rz

import tensorflow as tf

import shutil #roba fresca aggiunta da poco
import matplotlib.pyplot as plt

# Some modules to display an animation using imageio.
import imageio
from IPython import display
from urllib import request
from tensorflow_docs.vis import embed

# %% [markdown]
# # Fase di Pre-Processing

# %% [markdown]
# Definire la funzione `get_class` che recupera il nome della classe da un nome di file. Quindi, creare una funzione chiamata `get_files_per_class` che converte l'elenco di tutti i file (file sopra) in un dizionario che elenca i file per ogni classe:

# %%
def get_class(fname):
  """ Retrieve the name of the class given a filename.

    Args:
      fname: Name of the file in the UCF101 dataset.

    Returns:
      Class that the file belongs to.
  """
  return fname.split('_')[-7]

# %%
def get_files_per_class(files):
  """ Retrieve the files that belong to each class.

    Args:
      files: List of files in the dataset.

    Returns:
      Dictionary of class names (key) and files (values). 
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %% [markdown]
# Once you have the list of files per class, you can choose how many classes you would like to use and how many videos you would like per class in order to create your dataset.

# %%
download_dir = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val")

video_count_train = len(list(download_dir.glob('Train/*/*.avi')))
video_count_val = len(list(download_dir.glob('Validation/*/*.avi')))
video_count_test = len(list(download_dir.glob('Test/*/*.avi')))
video_total = video_count_train + video_count_val + video_count_test

print(f"print_train: {video_count_train}")
print(f"print_val: {video_count_val}")
print(f"print_test: {video_count_test}")
print(f"Total videos: {video_total}")
# Out:
# print_train: 960
# print_val: 160
# print_test: 160
# Total videos: 1280

# %% [markdown]
# # Crea fotogrammi da ogni file video

# %% [markdown]
# La funzione `frames_from_video_file` divide i video in frame, legge un intervallo scelto a caso di `n_frames` da un file video e li restituisce come array NumPy. Per ridurre la memoria e il sovraccarico di calcolo, scegliere un **piccolo** numero di fotogrammi. Inoltre, scegli lo stesso numero di fotogrammi da ogni video, il che rende più facile lavorare su lotti di dati.

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.
    
    Args:
      frame: Image that needs to resized and padded. 
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

# %%
def frames_from_video_file(video_path, n_frames, output_size = (80, 120), frame_step = 2):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))  

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

# %% [markdown]
# # Visualizza dati video

# %% [markdown]
# Snippet di codice per fare un gif dato un video preso a caso nella cartella di Train

# %%
def to_gif(images):
  converted_images = np.clip(images * 255, 0, 255).astype(np.uint8)
  imageio.mimsave('./animation.gif', converted_images, duration = 125)
  return embed.embed_file('./animation.gif')

# docs-infra: no-execute
ucf_sample_video = frames_from_video_file(next(download_dir.glob('Train/*/*.avi')), 60)
to_gif(ucf_sample_video)
# Out:
# <img src="data:image/gif;base64,..."/>

# %% [markdown]
# Successivamente, definire la classe `FrameGenerator` per creare un oggetto iterabile in grado di immettere dati nella pipeline di dati TensorFlow. La funzione generatore (`__call__`) produce l'array di frame prodotto da `frames_from_video_file` e un vettore codificato one-hot dell'etichetta associata all'insieme di frame.

# %%
class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label. 

      Args:
        path: Video file paths.
        n_frames: Number of frames. 
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.avi'))
    classes = [p.parent.name for p in video_paths] 
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames) 
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %% [markdown]
# ## Configurazione sul dataset per le perfomance
#
# Utilizzare il prefetching con buffer in modo da poter produrre dati dal disco senza che l'I/O diventi un blocco. Due funzioni importanti da utilizzare durante il caricamento dei dati sono:
#
# * `Dataset.cache`: mantiene i set di frame in memoria dopo che sono stati caricati dal disco durante la prima epoca. Questa funzione assicura che il set di dati non diventi un collo di bottiglia durante l'addestramento del modello. Se il tuo set di dati è troppo grande per entrare in memoria, puoi anche usare questo metodo per creare una cache su disco performante.
#
# * `Dataset.prefetch`: sovrappone la preelaborazione dei dati e l'esecuzione del modello durante l'addestramento.

# %% [markdown]
# Per preparare i dati da immessi nel modello, utilizzare il batching come mostrato di seguito. Si noti che quando si lavora con dati video, come i file AVI, i dati dovrebbero essere modellati come un oggetto a cinque dimensioni. Queste dimensioni sono le seguenti:`[batch_size, number_of_frames, height, width, channels]`. In confronto, un'immagine avrebbe quattro dimensioni:`[batch_size, height, width, channels]`. L'immagine qui sotto è un'illustrazione di come viene rappresentata la forma dei dati video.
#
# ![Video data shape](https://www.tensorflow.org/images/tutorials/video/video_data_shape.png)

# %%
n_frames = 60
batch_size = 32

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_path = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Train")
test_path = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Test")
val_path = pathlib.Path("C:/Users/Vincenzo\Desktop/Progetto/Lips_video_10_seconds_division_train_test_val/Validation")


train_ds = tf.data.Dataset.from_generator(FrameGenerator(train_path, n_frames, training=True),
                                          output_signature = output_signature)
# Batch the data
train_ds = train_ds.batch(batch_size)


val_ds = tf.data.Dataset.from_generator(FrameGenerator(val_path, n_frames),
                                        output_signature = output_signature)
val_ds = val_ds.batch(batch_size)


test_ds = tf.data.Dataset.from_generator(FrameGenerator(test_path, n_frames),
                                         output_signature = output_signature)
test_ds = test_ds.batch(batch_size)

# %% [markdown]
# ## Definire la rete
#
# Ora che hai creato un TensorFlow `Dataset` di fotogrammi video con le loro etichette, puoi usarlo con un modello di apprendimento profondo. Il seguente modello di classificazione che utilizza un modello  [EfficientNet](https://arxiv.org/abs/1905.11946){:.external}  pre-addestrato:

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

net = tf.keras.applications.EfficientNetB0(include_top = False)
net.trainable = False

# Definizione del modello
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(scale=255),
    tf.keras.layers.TimeDistributed(net),
    tf.keras.layers.Dense(8),
    tf.keras.layers.GlobalAveragePooling3D(),
])

# %%
model.compile(optimizer = optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
history = model.fit(train_ds, 
          epochs = 150,
          shuffle = False,
          validation_data = val_ds)
          #callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))
# Out:
# Epoch 1/150
# 30/30 [==============================] - 518s 17s/step - loss: 2.1504 - accuracy: 0.0927 - val_loss: 2.0290 - val_accuracy: 0.1375
# Epoch 2/150
# 30/30 [==============================] - 480s 16s/step - loss: 2.0645 - accuracy: 0.1594 - val_loss: 1.9858 - val_accuracy: 0.2688
# Epoch 3/150
# 30/30 [==============================] - 472s 16s/step - loss: 2.0318 - accuracy: 0.1937 - val_loss: 1.9623 - val_accuracy: 0.2750
# Epoch 4/150
# 30/30 [==============================] - 488s 16s/step - loss: 2.0009 - accuracy: 0.2427 - val_loss: 1.9421 - val_accuracy: 0.2875
# Epoch 5/150
# 30/30 [==============================] - 503s 17s/step - loss: 1.9766 - accuracy: 0.2438 - val_loss: 1.9316 - val_accuracy: 0.3125
# Epoch 6/150
# 30/30 [==============================] - 488s 16s/step - loss: 1.9497 - accuracy: 0.2875 - val_loss: 1.9210 - val_accuracy: 0.2812
# Epoch 7/150
# 30/30 [==============================] - 475s 16s/step - loss: 1.9255 - accuracy: 0.3260 - val_loss: 1.9107 - val_accuracy: 0.3375
# Epoch 8/150
# 30/30 [==============================] - 451s 15s/step - loss: 1.9040 - accuracy: 0.3552 - val_loss: 1.8920 - val_accuracy: 0.3313
# Epoch 9/150
# 30/30 [==============================] - 451s 15s/step - loss: 1.8838 - accuracy: 0.3510 - val_loss: 1.8832 - val_accuracy: 0.3625
# Epoch 10/150
# 30/30 [==============================] - 450s 15s/step - loss: 1.8668 - accuracy: 0.3812 - val_loss: 1.8792 - val_accuracy: 0.3375
# Epoch 11/150
# 30/30 [==============================] - 450s 15s/step - loss: 1.8429 - accuracy: 0.3917 - val_loss: 1.8659 - val_accuracy: 0.3438
# Epoch 12/150
# 30/30 [==============================] - 451s 15s/step - loss: 1.8332 - accuracy: 0.3958 - val_loss: 1.8526 - val_accuracy: 0.4000
# Epoch 13/150
# 30/30 [==============================] - 473s 16s/step - loss: 1.8129 - accuracy: 0.4135 - val_loss: 1.8491 - val_accuracy: 0.3625
# Epoch 14/150
# 30/30 [==============================] - 500s 17s/step - loss: 1.7957 - accuracy: 0.4250 - val_loss: 1.8361 - val_accuracy: 0.3750
# Epoch 15/150
# 30/30 [==============================] - 487s 16s/step - loss: 1.7848 - accuracy: 0.4281 - val_loss: 1.8427 - val_accuracy: 0.3875
# Epoch 16/150
# 30/30 [==============================] - 462s 15s/step - loss: 1.7687 - accuracy: 0.4167 - val_loss: 1.8300 - val_accuracy: 0.4187
# Epoch 17/150
# 30/30 [==============================] - 459s 15s/step - loss: 1.7554 - accuracy: 0.4437 - val_loss: 1.8158 - val_accuracy: 0.4062
# Epoch 18/150
# 30/30 [==============================] - 454s 15s/step - loss: 1.7421 - accuracy: 0.4365 - val_loss: 1.8134 - val_accuracy: 0.4062
# Epoch 19/150
# 30/30 [==============================] - 452s 15s/step - loss: 1.7292 - accuracy: 0.4490 - val_loss: 1.8101 - val_accuracy: 0.4000
# Epoch 20/150
# 30/30 [==============================] - 452s 15s/step - loss: 1.7158 - accuracy: 0.4583 - val_loss: 1.8005 - val_accuracy: 0.3938
# Epoch 21/150
# 30/30 [==============================] - 452s 15s/step - loss: 1.7015 - accuracy: 0.4573 - val_loss: 1.8080 - val_accuracy: 0.4187
# Epoch 22/150
# 30/30 [==============================] - 451s 15s/step - loss: 1.6957 - accuracy: 0.4542 - val_loss: 1.8047 - val_accuracy: 0.4125
# Epoch 23/150
# 30/30 [==============================] - 452s 15s/step - loss: 1.6822 - accuracy: 0.4698 - val_loss: 1.7850 - val_accuracy: 0.4062
# Epoch 24/150
# 30/30 [==============================] - 451s 15s/step - loss: 1.6756 - accuracy: 0.4750 - val_loss: 1.7885 - val_accuracy: 0.4187
# Epoch 25/150
# 30/30 [==============================] - 453s 15s/step - loss: 1.6634 - accuracy: 0.4708 - val_loss: 1.7733 - val_accuracy: 0.3750
# Epoch 26/150
# 30/30 [==============================] - 452s 15s/step - loss: 1.6533 - accuracy: 0.4698 - val_loss: 1.7818 - val_accuracy: 0.4125
# Epoch 27/150
# 30/30 [==============================] - 464s 16s/step - loss: 1.6384 - accuracy: 0.4844 - val_loss: 1.7859 - val_accuracy: 0.3625
# Epoch 28/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.6312 - accuracy: 0.4917 - val_loss: 1.7619 - val_accuracy: 0.4313
# Epoch 29/150
# 30/30 [==============================] - 490s 16s/step - loss: 1.6255 - accuracy: 0.4938 - val_loss: 1.7650 - val_accuracy: 0.4313
# Epoch 30/150
# 30/30 [==============================] - 493s 17s/step - loss: 1.6105 - accuracy: 0.4948 - val_loss: 1.7644 - val_accuracy: 0.4062
# Epoch 31/150
# 30/30 [==============================] - 493s 16s/step - loss: 1.5937 - accuracy: 0.5115 - val_loss: 1.7601 - val_accuracy: 0.3938
# Epoch 32/150
# 30/30 [==============================] - 479s 16s/step - loss: 1.5929 - accuracy: 0.4979 - val_loss: 1.7644 - val_accuracy: 0.3875
# Epoch 33/150
# 30/30 [==============================] - 461s 15s/step - loss: 1.5838 - accuracy: 0.5073 - val_loss: 1.7591 - val_accuracy: 0.4000
# Epoch 34/150
# 30/30 [==============================] - 457s 15s/step - loss: 1.5728 - accuracy: 0.5198 - val_loss: 1.7623 - val_accuracy: 0.3750
# Epoch 35/150
# 30/30 [==============================] - 456s 15s/step - loss: 1.5693 - accuracy: 0.5292 - val_loss: 1.7533 - val_accuracy: 0.3562
# Epoch 36/150
# 30/30 [==============================] - 458s 15s/step - loss: 1.5589 - accuracy: 0.5292 - val_loss: 1.7414 - val_accuracy: 0.4000
# Epoch 37/150
# 30/30 [==============================] - 458s 15s/step - loss: 1.5531 - accuracy: 0.5229 - val_loss: 1.7560 - val_accuracy: 0.3688
# Epoch 38/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.5399 - accuracy: 0.5365 - val_loss: 1.7414 - val_accuracy: 0.4187
# Epoch 39/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.5312 - accuracy: 0.5365 - val_loss: 1.7502 - val_accuracy: 0.4187
# Epoch 40/150
# 30/30 [==============================] - 507s 17s/step - loss: 1.5259 - accuracy: 0.5385 - val_loss: 1.7528 - val_accuracy: 0.3875
# Epoch 41/150
# 30/30 [==============================] - 504s 17s/step - loss: 1.5216 - accuracy: 0.5312 - val_loss: 1.7573 - val_accuracy: 0.3688
# Epoch 42/150
# 30/30 [==============================] - 507s 17s/step - loss: 1.5118 - accuracy: 0.5437 - val_loss: 1.7402 - val_accuracy: 0.4125
# Epoch 43/150
# 30/30 [==============================] - 558s 19s/step - loss: 1.4970 - accuracy: 0.5583 - val_loss: 1.7249 - val_accuracy: 0.4375
# Epoch 44/150
# 30/30 [==============================] - 546s 18s/step - loss: 1.4984 - accuracy: 0.5510 - val_loss: 1.7497 - val_accuracy: 0.4062
# Epoch 45/150
# 30/30 [==============================] - 529s 18s/step - loss: 1.4951 - accuracy: 0.5500 - val_loss: 1.7250 - val_accuracy: 0.4062
# Epoch 46/150
# 30/30 [==============================] - 509s 17s/step - loss: 1.4826 - accuracy: 0.5594 - val_loss: 1.7290 - val_accuracy: 0.4000
# Epoch 47/150
# 30/30 [==============================] - 503s 17s/step - loss: 1.4762 - accuracy: 0.5635 - val_loss: 1.7312 - val_accuracy: 0.4062
# Epoch 48/150
# 30/30 [==============================] - 498s 17s/step - loss: 1.4718 - accuracy: 0.5646 - val_loss: 1.7378 - val_accuracy: 0.4062
# Epoch 49/150
# 30/30 [==============================] - 509s 17s/step - loss: 1.4714 - accuracy: 0.5562 - val_loss: 1.7208 - val_accuracy: 0.4000
# Epoch 50/150
# 30/30 [==============================] - 497s 17s/step - loss: 1.4518 - accuracy: 0.5792 - val_loss: 1.7214 - val_accuracy: 0.4000
# Epoch 51/150
# 30/30 [==============================] - 499s 17s/step - loss: 1.4598 - accuracy: 0.5646 - val_loss: 1.7497 - val_accuracy: 0.4187
# Epoch 52/150
# 30/30 [==============================] - 502s 17s/step - loss: 1.4453 - accuracy: 0.5635 - val_loss: 1.7283 - val_accuracy: 0.3812
# Epoch 53/150
# 30/30 [==============================] - 496s 17s/step - loss: 1.4416 - accuracy: 0.5719 - val_loss: 1.7238 - val_accuracy: 0.4062
# Epoch 54/150
# 30/30 [==============================] - 507s 17s/step - loss: 1.4301 - accuracy: 0.5750 - val_loss: 1.7133 - val_accuracy: 0.4187
# Epoch 55/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.4254 - accuracy: 0.5760 - val_loss: 1.7261 - val_accuracy: 0.4062
# Epoch 56/150
# 30/30 [==============================] - 512s 17s/step - loss: 1.4245 - accuracy: 0.5823 - val_loss: 1.7353 - val_accuracy: 0.3875
# Epoch 57/150
# 30/30 [==============================] - 522s 18s/step - loss: 1.4107 - accuracy: 0.5896 - val_loss: 1.7376 - val_accuracy: 0.4313
# Epoch 58/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.4144 - accuracy: 0.5896 - val_loss: 1.7245 - val_accuracy: 0.3938
# Epoch 59/150
# 30/30 [==============================] - 509s 17s/step - loss: 1.3980 - accuracy: 0.6062 - val_loss: 1.7279 - val_accuracy: 0.3875
# Epoch 60/150
# 30/30 [==============================] - 524s 18s/step - loss: 1.3934 - accuracy: 0.6010 - val_loss: 1.7269 - val_accuracy: 0.4062
# Epoch 61/150
# 30/30 [==============================] - 547s 18s/step - loss: 1.3906 - accuracy: 0.5927 - val_loss: 1.7170 - val_accuracy: 0.4250
# Epoch 62/150
# 30/30 [==============================] - 521s 17s/step - loss: 1.3915 - accuracy: 0.5854 - val_loss: 1.7433 - val_accuracy: 0.4000
# Epoch 63/150
# 30/30 [==============================] - 518s 17s/step - loss: 1.3852 - accuracy: 0.6031 - val_loss: 1.7390 - val_accuracy: 0.4000
# Epoch 64/150
# 30/30 [==============================] - 521s 17s/step - loss: 1.3780 - accuracy: 0.5969 - val_loss: 1.7239 - val_accuracy: 0.4062
# Epoch 65/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.3718 - accuracy: 0.6000 - val_loss: 1.7195 - val_accuracy: 0.4000
# Epoch 66/150
# 30/30 [==============================] - 505s 17s/step - loss: 1.3697 - accuracy: 0.6115 - val_loss: 1.7241 - val_accuracy: 0.3875
# Epoch 67/150
# 30/30 [==============================] - 532s 18s/step - loss: 1.3606 - accuracy: 0.6094 - val_loss: 1.7066 - val_accuracy: 0.4250
# Epoch 68/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.3508 - accuracy: 0.6052 - val_loss: 1.7158 - val_accuracy: 0.4250
# Epoch 69/150
# 30/30 [==============================] - 513s 17s/step - loss: 1.3430 - accuracy: 0.6115 - val_loss: 1.7312 - val_accuracy: 0.4062
# Epoch 70/150
# 30/30 [==============================] - 512s 17s/step - loss: 1.3475 - accuracy: 0.6021 - val_loss: 1.7201 - val_accuracy: 0.4062
# Epoch 71/150
# 30/30 [==============================] - 518s 17s/step - loss: 1.3379 - accuracy: 0.6083 - val_loss: 1.7201 - val_accuracy: 0.4500
# Epoch 72/150
# 30/30 [==============================] - 517s 17s/step - loss: 1.3360 - accuracy: 0.6094 - val_loss: 1.7225 - val_accuracy: 0.3938
# Epoch 73/150
# 30/30 [==============================] - 514s 17s/step - loss: 1.3226 - accuracy: 0.6198 - val_loss: 1.7140 - val_accuracy: 0.3875
# Epoch 74/150
# 30/30 [==============================] - 527s 18s/step - loss: 1.3273 - accuracy: 0.6208 - val_loss: 1.7133 - val_accuracy: 0.3875
# Epoch 75/150
# 30/30 [==============================] - 528s 18s/step - loss: 1.3187 - accuracy: 0.6219 - val_loss: 1.7282 - val_accuracy: 0.3938
# Epoch 76/150
# 30/30 [==============================] - 512s 17s/step - loss: 1.3095 - accuracy: 0.6240 - val_loss: 1.7196 - val_accuracy: 0.3875
# Epoch 77/150
# 30/30 [==============================] - 520s 17s/step - loss: 1.3086 - accuracy: 0.6323 - val_loss: 1.6975 - val_accuracy: 0.4313
# Epoch 78/150
# 30/30 [==============================] - 551s 19s/step - loss: 1.3028 - accuracy: 0.6302 - val_loss: 1.7358 - val_accuracy: 0.3875
# Epoch 79/150
# 30/30 [==============================] - 537s 18s/step - loss: 1.3047 - accuracy: 0.6333 - val_loss: 1.7185 - val_accuracy: 0.4062
# Epoch 80/150
# 30/30 [==============================] - 520s 17s/step - loss: 1.2931 - accuracy: 0.6240 - val_loss: 1.7076 - val_accuracy: 0.4000
# Epoch 81/150
# 30/30 [==============================] - 529s 18s/step - loss: 1.2873 - accuracy: 0.6427 - val_loss: 1.7254 - val_accuracy: 0.3938
# Epoch 82/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.2922 - accuracy: 0.6240 - val_loss: 1.7152 - val_accuracy: 0.4437
# Epoch 83/150
# 30/30 [==============================] - 507s 17s/step - loss: 1.2791 - accuracy: 0.6385 - val_loss: 1.7085 - val_accuracy: 0.4187
# Epoch 84/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.2767 - accuracy: 0.6281 - val_loss: 1.7157 - val_accuracy: 0.4250
# Epoch 85/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.2747 - accuracy: 0.6333 - val_loss: 1.7006 - val_accuracy: 0.4187
# Epoch 86/150
# 30/30 [==============================] - 533s 18s/step - loss: 1.2681 - accuracy: 0.6500 - val_loss: 1.7154 - val_accuracy: 0.4187
# Epoch 87/150
# 30/30 [==============================] - 516s 17s/step - loss: 1.2623 - accuracy: 0.6562 - val_loss: 1.7188 - val_accuracy: 0.4000
# Epoch 88/150
# 30/30 [==============================] - 522s 17s/step - loss: 1.2611 - accuracy: 0.6448 - val_loss: 1.7246 - val_accuracy: 0.4187
# Epoch 89/150
# 30/30 [==============================] - 542s 18s/step - loss: 1.2515 - accuracy: 0.6396 - val_loss: 1.7081 - val_accuracy: 0.4313
# Epoch 90/150
# 30/30 [==============================] - 541s 18s/step - loss: 1.2557 - accuracy: 0.6396 - val_loss: 1.7103 - val_accuracy: 0.4313
# Epoch 91/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.2451 - accuracy: 0.6552 - val_loss: 1.6919 - val_accuracy: 0.4250
# Epoch 92/150
# 30/30 [==============================] - 506s 17s/step - loss: 1.2454 - accuracy: 0.6500 - val_loss: 1.7267 - val_accuracy: 0.4187
# Epoch 93/150
# 30/30 [==============================] - 505s 17s/step - loss: 1.2401 - accuracy: 0.6469 - val_loss: 1.7186 - val_accuracy: 0.4125
# Epoch 94/150
# 30/30 [==============================] - 519s 17s/step - loss: 1.2364 - accuracy: 0.6552 - val_loss: 1.7070 - val_accuracy: 0.4313
# Epoch 95/150
# 30/30 [==============================] - 553s 19s/step - loss: 1.2325 - accuracy: 0.6469 - val_loss: 1.7063 - val_accuracy: 0.4250
# Epoch 96/150
# 30/30 [==============================] - 511s 17s/step - loss: 1.2306 - accuracy: 0.6469 - val_loss: 1.7173 - val_accuracy: 0.4250
# Epoch 97/150
# 30/30 [==============================] - 544s 18s/step - loss: 1.2264 - accuracy: 0.6625 - val_loss: 1.6978 - val_accuracy: 0.4000
# Epoch 98/150
# 30/30 [==============================] - 509s 17s/step - loss: 1.2260 - accuracy: 0.6667 - val_loss: 1.7088 - val_accuracy: 0.4313
# Epoch 99/150
# 30/30 [==============================] - 503s 17s/step - loss: 1.2133 - accuracy: 0.6750 - val_loss: 1.7115 - val_accuracy: 0.4313
# Epoch 100/150
# 30/30 [==============================] - 548s 18s/step - loss: 1.2084 - accuracy: 0.6719 - val_loss: 1.7212 - val_accuracy: 0.4313
# Epoch 101/150
# 30/30 [==============================] - 546s 18s/step - loss: 1.2061 - accuracy: 0.6635 - val_loss: 1.7256 - val_accuracy: 0.4187
# Epoch 102/150
# 30/30 [==============================] - 545s 18s/step - loss: 1.2019 - accuracy: 0.6719 - val_loss: 1.7215 - val_accuracy: 0.4062
# Epoch 103/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.2060 - accuracy: 0.6490 - val_loss: 1.7123 - val_accuracy: 0.4313
# Epoch 104/150
# 30/30 [==============================] - 518s 17s/step - loss: 1.1989 - accuracy: 0.6604 - val_loss: 1.7215 - val_accuracy: 0.4062
# Epoch 105/150
# 30/30 [==============================] - 511s 17s/step - loss: 1.1949 - accuracy: 0.6656 - val_loss: 1.7126 - val_accuracy: 0.4187
# Epoch 106/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.1975 - accuracy: 0.6594 - val_loss: 1.7011 - val_accuracy: 0.4000
# Epoch 107/150
# 30/30 [==============================] - 512s 17s/step - loss: 1.1955 - accuracy: 0.6760 - val_loss: 1.7125 - val_accuracy: 0.4313
# Epoch 108/150
# 30/30 [==============================] - 511s 17s/step - loss: 1.1836 - accuracy: 0.6708 - val_loss: 1.7206 - val_accuracy: 0.4250
# Epoch 109/150
# 30/30 [==============================] - 509s 17s/step - loss: 1.1852 - accuracy: 0.6687 - val_loss: 1.7264 - val_accuracy: 0.4187
# Epoch 110/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.1736 - accuracy: 0.6740 - val_loss: 1.7163 - val_accuracy: 0.4250
# Epoch 111/150
# 30/30 [==============================] - 510s 17s/step - loss: 1.1693 - accuracy: 0.6750 - val_loss: 1.7152 - val_accuracy: 0.4250
# Epoch 112/150
# 30/30 [==============================] - 520s 17s/step - loss: 1.1708 - accuracy: 0.6792 - val_loss: 1.7262 - val_accuracy: 0.4375
# Epoch 113/150
# 30/30 [==============================] - 520s 17s/step - loss: 1.1633 - accuracy: 0.6771 - val_loss: 1.7060 - val_accuracy: 0.4375
# Epoch 114/150
# 30/30 [==============================] - 519s 17s/step - loss: 1.1575 - accuracy: 0.6906 - val_loss: 1.7133 - val_accuracy: 0.4125
# Epoch 115/150
# 30/30 [==============================] - 523s 18s/step - loss: 1.1588 - accuracy: 0.6771 - val_loss: 1.7167 - val_accuracy: 0.4187
# Epoch 116/150
# 30/30 [==============================] - 534s 18s/step - loss: 1.1546 - accuracy: 0.6740 - val_loss: 1.7276 - val_accuracy: 0.4187
# Epoch 117/150
# 30/30 [==============================] - 528s 18s/step - loss: 1.1499 - accuracy: 0.6750 - val_loss: 1.7026 - val_accuracy: 0.4125
# Epoch 118/150
# 30/30 [==============================] - 517s 17s/step - loss: 1.1494 - accuracy: 0.6802 - val_loss: 1.7116 - val_accuracy: 0.4250
# Epoch 119/150
# 30/30 [==============================] - 522s 17s/step - loss: 1.1477 - accuracy: 0.6698 - val_loss: 1.7006 - val_accuracy: 0.4375
# Epoch 120/150
# 30/30 [==============================] - 522s 17s/step - loss: 1.1357 - accuracy: 0.6979 - val_loss: 1.6935 - val_accuracy: 0.4437
# Epoch 121/150
# 30/30 [==============================] - 521s 17s/step - loss: 1.1390 - accuracy: 0.6823 - val_loss: 1.7322 - val_accuracy: 0.4313
# Epoch 122/150
# 30/30 [==============================] - 517s 17s/step - loss: 1.1256 - accuracy: 0.7010 - val_loss: 1.7311 - val_accuracy: 0.4313
# Epoch 123/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.1405 - accuracy: 0.6802 - val_loss: 1.7100 - val_accuracy: 0.4187
# Epoch 124/150
# 30/30 [==============================] - 519s 17s/step - loss: 1.1347 - accuracy: 0.6917 - val_loss: 1.7232 - val_accuracy: 0.4563
# Epoch 125/150
# 30/30 [==============================] - 528s 18s/step - loss: 1.1240 - accuracy: 0.6865 - val_loss: 1.7173 - val_accuracy: 0.4187
# Epoch 126/150
# 30/30 [==============================] - 515s 17s/step - loss: 1.1209 - accuracy: 0.6792 - val_loss: 1.7164 - val_accuracy: 0.3875
# Epoch 127/150
# 30/30 [==============================] - 525s 18s/step - loss: 1.1239 - accuracy: 0.6854 - val_loss: 1.7397 - val_accuracy: 0.4062
# Epoch 128/150
# 30/30 [==============================] - 523s 17s/step - loss: 1.1235 - accuracy: 0.6969 - val_loss: 1.7056 - val_accuracy: 0.4187
# Epoch 129/150
# 30/30 [==============================] - 527s 18s/step - loss: 1.1120 - accuracy: 0.6906 - val_loss: 1.7143 - val_accuracy: 0.4187
# Epoch 130/150
# 30/30 [==============================] - 527s 18s/step - loss: 1.1122 - accuracy: 0.6917 - val_loss: 1.7151 - val_accuracy: 0.4437
# Epoch 131/150
# 30/30 [==============================] - 526s 18s/step - loss: 1.1107 - accuracy: 0.6979 - val_loss: 1.7174 - val_accuracy: 0.3875
# Epoch 132/150
# 30/30 [==============================] - 523s 18s/step - loss: 1.1056 - accuracy: 0.6958 - val_loss: 1.7292 - val_accuracy: 0.4187
# Epoch 133/150
# 30/30 [==============================] - 523s 18s/step - loss: 1.1107 - accuracy: 0.6917 - val_loss: 1.7398 - val_accuracy: 0.3875
# Epoch 134/150
# 30/30 [==============================] - 523s 18s/step - loss: 1.1082 - accuracy: 0.7000 - val_loss: 1.7169 - val_accuracy: 0.4313
# Epoch 135/150
# 30/30 [==============================] - 523s 18s/step - loss: 1.0966 - accuracy: 0.7042 - val_loss: 1.7452 - val_accuracy: 0.4375
# Epoch 136/150
# 30/30 [==============================] - 523s 18s/step - loss: 1.0895 - accuracy: 0.6958 - val_loss: 1.7115 - val_accuracy: 0.4250
# Epoch 137/150
# 30/30 [==============================] - 522s 17s/step - loss: 1.0820 - accuracy: 0.7073 - val_loss: 1.7206 - val_accuracy: 0.4062
# Epoch 138/150
# 30/30 [==============================] - 524s 18s/step - loss: 1.0985 - accuracy: 0.7000 - val_loss: 1.7051 - val_accuracy: 0.4437
# Epoch 139/150
# 30/30 [==============================] - 524s 18s/step - loss: 1.0866 - accuracy: 0.7000 - val_loss: 1.7119 - val_accuracy: 0.4250
# Epoch 140/150
# 30/30 [==============================] - 532s 18s/step - loss: 1.0753 - accuracy: 0.7042 - val_loss: 1.7043 - val_accuracy: 0.4375
# Epoch 141/150
# 30/30 [==============================] - 529s 18s/step - loss: 1.0818 - accuracy: 0.7073 - val_loss: 1.7068 - val_accuracy: 0.4187
# Epoch 142/150
# 30/30 [==============================] - 529s 18s/step - loss: 1.0813 - accuracy: 0.7177 - val_loss: 1.7224 - val_accuracy: 0.4125
# Epoch 143/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.0718 - accuracy: 0.7094 - val_loss: 1.7179 - val_accuracy: 0.4250
# Epoch 144/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.0631 - accuracy: 0.7146 - val_loss: 1.7245 - val_accuracy: 0.4563
# Epoch 145/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.0646 - accuracy: 0.7031 - val_loss: 1.7004 - val_accuracy: 0.4000
# Epoch 146/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.0643 - accuracy: 0.7000 - val_loss: 1.7268 - val_accuracy: 0.4187
# Epoch 147/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.0580 - accuracy: 0.7156 - val_loss: 1.7231 - val_accuracy: 0.4062
# Epoch 148/150
# 30/30 [==============================] - 531s 18s/step - loss: 1.0624 - accuracy: 0.7135 - val_loss: 1.7209 - val_accuracy: 0.4313
# Epoch 149/150
# 30/30 [==============================] - 530s 18s/step - loss: 1.0553 - accuracy: 0.7198 - val_loss: 1.7294 - val_accuracy: 0.4250
# Epoch 150/150
# 30/30 [==============================] - 532s 18s/step - loss: 1.0517 - accuracy: 0.7167 - val_loss: 1.7312 - val_accuracy: 0.4313

# %% [markdown]
# ## Salvataggio parametri su file

# %%
filename = "2d_cnn_150_Vincenzo.txt"  # Nome del file di destinazione

with open(filename, "w") as file:
    file.write("Batch size: " + str(batch_size) + "\n")
    file.write("Shuffle: " + "False" + "\n")
    file.write("Numero frames: " + str(n_frames) + "\n")
    file.write("Frame step: " + "2" + "\n")
    file.write("Image res: " +  "120x80"  + "\n")
    file.write("Learning rate: Adam " + "(0.0001)" + "\n")

# %%
# Visualize the model
tf.keras.utils.plot_model(model, expand_nested=True, dpi=60, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
def plot_history(history):
  """
    Plotting training and validation learning curves.

    Args:
      history: model history with all the metric measures
  """
  fig, (ax1, ax2) = plt.subplots(2)

  fig.set_size_inches(18.5, 10.5)

  # Plot loss
  ax1.set_title('Loss')
  ax1.plot(history.history['loss'], label = 'train')
  ax1.plot(history.history['val_loss'], label = 'test')
  ax1.set_ylabel('Loss')

  # Determine upper bound of y-axis
  max_loss = max(history.history['loss'] + history.history['val_loss'])

  ax1.set_ylim([0, np.ceil(max_loss)])
  ax1.set_xlabel('Epoch')
  ax1.legend(['Train', 'Validation']) 

  # Plot accuracy
  ax2.set_title('Accuracy')
  ax2.plot(history.history['accuracy'],  label = 'train')
  ax2.plot(history.history['val_accuracy'], label = 'test')
  ax2.set_ylabel('Accuracy')
  ax2.set_ylim([0, 1])
  ax2.set_xlabel('Epoch')
  ax2.legend(['Train', 'Validation'])

  plt.show()

plot_history(history)

# %% [markdown]
# # Valutare il modello

# %%
model.evaluate(test_ds, return_dict=True)
# Out:
# 5/5 [==============================] - 77s 15s/step - loss: 1.6768 - accuracy: 0.4187
# {'loss': 1.6768341064453125, 'accuracy': 0.41874998807907104}

# %%
def get_actual_predicted_labels(dataset): 
  """
    Create a list of actual ground truth values and the predictions from the model.

    Args:
      dataset: An iterable data structure, such as a TensorFlow Dataset, with features and labels.

    Return:
      Ground truth and predicted values for a particular dataset.
  """
  actual = [labels for _, labels in dataset.unbatch()]
  predicted = model.predict(dataset)

  actual = tf.stack(actual, axis=0)
  predicted = tf.concat(predicted, axis=0)
  predicted = tf.argmax(predicted, axis=1)

  return actual, predicted

# %%
def plot_confusion_matrix(actual, predicted, labels, ds_type):
  cm = tf.math.confusion_matrix(actual, predicted)
  ax = sns.heatmap(cm, annot=True, fmt='g')
  sns.set(rc={'figure.figsize':(12, 12)})
  sns.set(font_scale=1.4)
  ax.set_title('Confusion matrix of babele for ' + ds_type)
  ax.set_xlabel('Predicted Language')
  ax.set_ylabel('Actual Language')
  plt.xticks(rotation=90)
  plt.yticks(rotation=0)
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
fg = FrameGenerator(train_path, n_frames, training=True)
labels = list(fg.class_ids_for_name.keys())

# Rename the labels based on the provided mapping
label_mapping = {
    1: 'Italian',
    2: 'English',
    3: 'German',
    4: 'Spanish',
    5: 'Dutch',
    6: 'Russian',
    7: 'Japanese',
    8: 'French'
}

labels = [int(label) for label in labels]

renamed_labels = [label_mapping[label_id] for label_id in labels]

# Print the renamed labels
print(renamed_labels)
# Out:
# ['Italian', 'English', 'German', 'Spanish', 'Dutch', 'Russian', 'Japanese', 'French']

# %%
actual, predicted = get_actual_predicted_labels(train_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'training')
# Out:
# 30/30 [==============================] - 457s 15s/step

# %%
actual, predicted = get_actual_predicted_labels(test_ds)
plot_confusion_matrix(actual, predicted, renamed_labels, 'test')
# Out:
# 5/5 [==============================] - 83s 16s/step

# %%
def calculate_classification_metrics(y_actual, y_pred, labels):
  """
    Calculate the precision and recall of a classification model using the ground truth and
    predicted values. 

    Args:
      y_actual: Ground truth labels.
      y_pred: Predicted labels.
      labels: List of classification labels.

    Return:
      Precision and recall measures.
  """
  cm = tf.math.confusion_matrix(y_actual, y_pred)
  tp = np.diag(cm) # Diagonal represents true positives
  precision = dict()
  recall = dict()
  for i in range(len(labels)):
    col = cm[:, i]
    fp = np.sum(col) - tp[i] # Sum of column minus true positive is false negative

    row = cm[i, :]
    fn = np.sum(row) - tp[i] # Sum of row minus true positive, is false negative

    precision[labels[i]] = tp[i] / (tp[i] + fp) # Precision 

    recall[labels[i]] = tp[i] / (tp[i] + fn) # Recall

  return precision, recall

# %%
precision, recall = calculate_classification_metrics(actual, predicted, renamed_labels) # Test dataset

# %%
precision
# Out:
# {'Italian': 0.3684210526315789,
#  'English': 0.0,
#  'German': 0.7272727272727273,
#  'Spanish': 0.07692307692307693,
#  'Dutch': 0.5625,
#  'Russian': 0.38461538461538464,
#  'Japanese': 0.3888888888888889,
#  'French': 0.4642857142857143}

# %%
recall
# Out:
# {'Italian': 0.35,
#  'English': 0.0,
#  'German': 0.8,
#  'Spanish': 0.05,
#  'Dutch': 0.9,
#  'Russian': 0.25,
#  'Japanese': 0.35,
#  'French': 0.65}

# %% [markdown]
# # Salvo il modello

# %%
# Save the weights
model.save_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_2D/2dcnn_150_epoche_ShuffleNO/Pesi_Modello/pesi_2dcnn_150_epoche_ShuffleNO')

# Restore the weights
model.load_weights('C:/Users/Vincenzo/Desktop/Materiale_Gruppo_24/Sperimentazioni_Reti_2D/2dcnn_150_epoche_ShuffleNO/Pesi_Modello/pesi_2dcnn_150_epoche_ShuffleNO')

model.compile(optimizer = optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# Evaluate the model
loss, acc = model.evaluate(test_ds, verbose=2)
print("Modello caricato: accuracy: {:5.2f}%".format(100 * acc))
# Out:
# 5/5 - 80s - loss: 1.6573 - accuracy: 0.4313 - 80s/epoch - 16s/step
# Modello caricato: accuracy: 43.13%
